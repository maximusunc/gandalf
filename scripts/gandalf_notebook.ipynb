# %%
"""Get all imports."""
import csv
import json
import time

import httpx
from bmt import Toolkit

from gandalf import (
    CSRGraph,
    analyze_node_types,
    analyze_predicates,
    build_graph_from_jsonl,
    debug_missing_edge,
    diagnose_graph_edge_storage,
    diagnose_path_explosion,
    find_mechanistic_paths,
    validate_trapi_response,
)
from gandalf.search import (
    _do_unfiltered_search,
    do_one_hop,
    lookup,
)

t0 = time.perf_counter()
bmt = Toolkit()
t1 = time.perf_counter()
print(f"BMT Initialization took: {t1 - t0} seconds.")
# Out:
# BMT Initialization took: 0.43700958299996273 seconds.

# %%
"""Build a new graph from jsonl files. Saves to pickle."""

# Build graph from edges and nodes
graph = build_graph_from_jsonl(
    edge_jsonl_path="../02_04_2026/edges.jsonl",
    node_jsonl_path="../02_04_2026/nodes.jsonl",
)

# Save for fast reloading
graph.save_mmap("../02_04_2026/gandalf_mmap")
print("Graph saved!")
# Out:
# Pass 1: Collecting vocabularies from ../02_04_2026/edges.jsonl...
#   1,000,000 edges scanned...
#   2,000,000 edges scanned...
#   3,000,000 edges scanned...
#   4,000,000 edges scanned...
#   5,000,000 edges scanned...
#   6,000,000 edges scanned...
#   7,000,000 edges scanned...
#   8,000,000 edges scanned...
#   9,000,000 edges scanned...
#   10,000,000 edges scanned...
#   11,000,000 edges scanned...
#   12,000,000 edges scanned...
#   13,000,000 edges scanned...
#   14,000,000 edges scanned...
#   15,000,000 edges scanned...
#   16,000,000 edges scanned...
#   17,000,000 edges scanned...
#   18,000,000 edges scanned...
#   19,000,000 edges scanned...
#   20,000,000 edges scanned...
#   21,000,000 edges scanned...
#   22,000,000 edges scanned...
#   23,000,000 edges scanned...
#   24,000,000 edges scanned...
#   25,000,000 edges scanned...
#   26,000,000 edges scanned...
#   27,000,000 edges scanned...
#   28,000,000 edges scanned...
#   29,000,000 edges scanned...
#   30,000,000 edges scanned...
#   31,000,000 edges scanned...
#   32,000,000 edges scanned...
#   33,000,000 edges scanned...
#   34,000,000 edges scanned...
#   35,000,000 edges scanned...
#   36,000,000 edges scanned...
#   37,000,000 edges scanned...
#   38,000,000 edges scanned...
#   Found 1,661,857 unique nodes, 52 predicates, 38,037,368 edges
# Reading node properties from ../02_04_2026/nodes.jsonl...
#   Loaded properties for 1,661,857 nodes
# Pass 2: Building arrays and property stores (38,037,368 edges)...
#   1,000,000/38,037,368 edges processed...
#   2,000,000/38,037,368 edges processed...
#   3,000,000/38,037,368 edges processed...
#   4,000,000/38,037,368 edges processed...
#   5,000,000/38,037,368 edges processed...
#   6,000,000/38,037,368 edges processed...
#   7,000,000/38,037,368 edges processed...
#   8,000,000/38,037,368 edges processed...
#   9,000,000/38,037,368 edges processed...
#   10,000,000/38,037,368 edges processed...
#   11,000,000/38,037,368 edges processed...

# %%
"""Load in a pickled graph."""

# Load saved graph (takes ~1-2 seconds instead of 280!)
graph = CSRGraph.load_mmap("../02_04_2026/gandalf_mmap")
# Out:
# Loading graph from ../02_04_2026/gandalf_mmap (mmap_mode=r)...
#   Edge property dedup: 38,037,368 edges -> 574 unique source configs, 3,639 unique qualifier combos
#   LMDB detail store: ../02_04_2026/gandalf_mmap/edge_properties.lmdb
# Graph loaded in 3.39s (edge_properties: 0.02s)
#   1,661,857 nodes, 38,037,368 edges, 52 predicates

# %%
CSRGraph.save_mmap(directory="../12_17_2025/gandalf_mmap")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 CSRGraph.save_mmap("../12_17_2025/gandalf_mmap")
#
# TypeError: CSRGraph.save_mmap() missing 1 required positional argument: 'directory'

# %%
"""Just set the start and end nodes you're looking for."""
start_node = "CHEBI:45783"  # Imatinib
end_node = "MONDO:0004979"  # Asthma
start_idx = graph.get_node_idx(start_node)
end_idx = graph.get_node_idx(end_node)

# %%
"""Get initial node degrees."""

start_idx = graph.get_node_idx(start_node)
end_idx = graph.get_node_idx(end_node)

print(f"Start degree: {graph.degree(start_idx):,}")
print(f"End degree: {len(graph.incoming_neighbors(end_idx)):,}")
# Out:
# Start degree: 6,776
# End degree: 18,748

# %%
"""Generate paths."""

start_time = time.time()
print(f"\nFinding 3-hop paths from {start_node} to {end_node}...")
paths = _do_unfiltered_search(graph, start_idx, end_idx, verbose=True)
print("Finding paths with properties took:", time.time() - start_time)
print("Total paths:", len(paths))

for path in paths[:3]:
    print(path)

# t0 = time.perf_counter()
# hydrated_paths = _return_with_properties(graph, paths, verbose=True)
# t1 = time.perf_counter()
# print("Hydration returned:", len(hydrated_paths), t1 - t0)

# for path in hydrated_paths[:3]:
#     print(path)
# Out:
# Finding 3-hop paths from CHEBI:45783 to MONDO:0004979...
# Imatinib 1-hop: 6776 2.1875021047890186e-05
# Imatinib 2-hop edges: 2198414 9.224366709007882
# Asthma 1-hop: 18748 1.879199407994747e-05
# Intersection edges: 417986 0.019268166972324252
# Finding paths with properties took: 9.295316934585571
# Total paths: 417986
# [151747, 70012, 129488, 306069]
# [151747, 70012, 144491, 306069]
# [151747, 70012, 148054, 306069]

# %%
valid_predicates = []
for predicate in ["biolink:treats",
        "biolink:affects",
        "biolink:regulates",
        "biolink:increases_expression_of",
        "biolink:decreases_expression_of",
        "biolink:gene_associated_with_condition",
        "biolink:has_metabolite",
        "biolink:metabolized_by",
        "biolink:applied_to_treat",
        "biolink:contraindicated_for",
        "biolink:directly_physically_interacts_with",
        "biolink:has_contraindication",
        "biolink:subject_of_treatment_application_or_study_for_treatment_by",
        "biolink:contribution_from"]:
    if bmt.get_element(predicate) is not None:
        valid_predicates.append(predicate)

print(valid_predicates)
# Out:
# ['biolink:treats', 'biolink:affects', 'biolink:regulates', 'biolink:gene_associated_with_condition', 'biolink:has_metabolite', 'biolink:applied_to_treat', 'biolink:directly_physically_interacts_with', 'biolink:has_contraindication', 'biolink:subject_of_treatment_application_or_study_for_treatment_by', 'biolink:contribution_from']

# %%
"""Do Pathfinder Imatinib to Asthma."""

t0 = time.perf_counter()

pathfinder_results = lookup(graph, {
  "message": {
    "query_graph": {
      "nodes": {
        "n0": {
          "ids": ["CHEBI:45783"]
        },
        "n1": {},
        "n2": {},
        "n3": {
          "ids": ["MONDO:0004979"]
        }
      },
      "edges": {
        "e0": {
          "subject": "n0",
          "object": "n1",
          "predicates": ["biolink:related_to"]
        },
        "e1": {
          "subject": "n1",
          "object": "n2",
          "predicates": ["biolink:related_to"]
        },
        "e2": {
          "subject": "n2",
          "object": "n3",
          "predicates": ["biolink:related_to"]
        }
      }
    }
  }
}, bmt)

t1 = time.perf_counter()
print(f"Pathfinder returned {len(pathfinder_results['message']['results'])} results in {t1 - t0}s")

# result = validate_trapi_response(graph, pathfinder_results)
# print(result.summary())
# Out:
# Using provided BMT instance
# Query graph: 4 nodes, 3 edges
#
# Processing edge 'e0': n0 -> n1
#   Query predicates: ['biolink:related_to']
#   Expanded to 0 forward, 0 inverse predicates
#   Forward search from 1 pinned nodes
#   [GC] Gen 1: 1.51s, collected 0 objects
#   [GC] Gen 2: 3.14s, collected 0 objects
#   Traversed 6,776 total neighbors
#   Slow nodes (>0.1s): 1
#     Node 151747: 6,776 neighbors, 4.66s
#   Found 6,317 matches in 4.659s
#   Found 6,317 matching edges
#   Remaining edges: 2
#
# Processing edge 'e2': n2 -> n3
#   Query predicates: ['biolink:related_to']
#   Expanded to 0 forward, 0 inverse predicates
#   Backward search from 1 pinned nodes
#   Traversed 18,748 total incoming neighbors
#   Found 18,499 matches in 0.094s
#   Found 18,499 matching edges
#   Remaining edges: 1
#
# Processing edge 'e1': n1 -> n2
#   Query predicates: ['biolink:related_to']
#   Expanded to 0 forward, 0 inverse predicates
#   Both ends pinned: 5176 start, 15120 end
#   [GC] Gen 2: 3.42s, collected 0 objects
#     Neighbor traversal: 4.513s (1,339,444 neighbors, 98,009 unique targets)
#     Intersection: 0.109s
#   Found 221,245 matches in 4.621s
#   Found 221,245 matching edges
#   Remaining edges: 0
#
# Reconstructing complete paths...
#   Join order: ['e0', 'e1', 'e2']
#   Starting with 6,317 paths from edge 'e0'
#   Join 1/2: Adding edge 'e1' (6,317 paths)... -> 317,755 paths (0.61s)
#   Join 2/2: Adding edge 'e2' (317,755 paths)... -> 563,467 paths (1.01s)
#   Path reconstruction took 1.63s
#   Enriching 563,467 paths (lightweight mode: >50,000 paths, skipping edge attributes)...
#   Cached properties for 10,357 unique nodes (0.07s)
#   [GC] Gen 0: 0.32s, collected 0 objects
#   Enrichment took 1.41s
# Found 563,467 complete paths
#   [GC] Gen 1: 0.55s, collected 0 objects
#   Grouped into 191,427 unique node paths (1.10s)
#   [GC] Gen 0: 0.62s, collected 0 objects
#   Built 191,427 results (3.42s)
#   Post-processing total: 4.52s
#   [GC Summary] 7250 collections, 9.86s total, 0 objects collected
# Pathfinder returned 191427 results in 19.018659583991393s

# %%
result = debug_missing_edge(graph, "NCBIGene:596", "biolink:affects", "CHEBI:30742")
print(result)

# print(diagnose_graph_edge_storage(graph, "GO:0022408"))
# Out:
# Debug report for missing edge:
#   Expected: NCBIGene:596 --[biolink:affects]--> CHEBI:30742
#
# Predicate info:
#   Predicate: biolink:affects
#   Is symmetric: False
#   Inverse: (none)
#
# Node existence:
#   Subject 'NCBIGene:596': EXISTS (idx=431713)
#   Object 'CHEBI:30742': EXISTS (idx=141868)
#
# Edges found between these nodes:
#   [forward] NCBIGene:596 --[biolink:affects]--> CHEBI:30742
#   [forward] NCBIGene:596 --[biolink:affects]--> CHEBI:30742
#   [reverse] CHEBI:30742 --[biolink:affects]--> NCBIGene:596
#   [reverse] CHEBI:30742 --[biolink:affects]--> NCBIGene:596
#   [reverse] CHEBI:30742 --[biolink:affects]--> NCBIGene:596
#
# Expected matches (any of these would validate):
#   1. Forward: NCBIGene:596 --[biolink:affects]--> CHEBI:30742
#
# Subject 'NCBIGene:596' neighbors (first 10):
#   -> CHEBI:133021 via ['biolink:interacts_with']
#   -> CHEBI:16991 via ['biolink:coexists_with', 'biolink:interacts_with']
#   -> CHEBI:16991 via ['biolink:coexists_with', 'biolink:interacts_with']
#   -> CHEBI:18070 via ['biolink:affects']
#   -> CHEBI:23367 via ['biolink:subclass_of']
#   -> CHEBI:24431 via ['biolink:subclass_of']
#   -> CHEBI:27899 via ['biolink:affects', 'biolink:interacts_with']
#   -> CHEBI:27899 via ['biolink:affects', 'biolink:interacts_with']
#   -> CHEBI:30742 via ['biolink:affects', 'biolink:affects']
#   -> CHEBI:30742 via ['biolink:affects', 'biolink:affects']
#   ... and 2086 more
#
# Object 'CHEBI:30742' incoming neighbors (first 10):
#   <- CHEBI:125669 via ['biolink:related_to']
#   <- CHEBI:131194 via ['biolink:interacts_with']
#   <- CHEBI:131391 via ['biolink:related_to']
#   <- CHEBI:15377 via ['biolink:affects', 'biolink:coexists_with', 'biolink:interacts_with', 'biolink:related_to']
#   <- CHEBI:15377 via ['biolink:affects', 'biolink:coexists_with', 'biolink:interacts_with', 'biolink:related_to']
#   <- CHEBI:15377 via ['biolink:affects', 'biolink:coexists_with', 'biolink:interacts_with', 'biolink:related_to']
#   <- CHEBI:15377 via ['biolink:affects', 'biolink:coexists_with', 'biolink:interacts_with', 'biolink:related_to']
#   <- CHEBI:16236 via ['biolink:coexists_with', 'biolink:interacts_with']
#   <- CHEBI:16236 via ['biolink:coexists_with', 'biolink:interacts_with']
#   <- CHEBI:16247 via ['biolink:interacts_with']
#   ... and 149 more

# %%
"""Get meaningful or mechanistic paths."""

# print("\n=== EXCLUDING ONTOLOGY HIERARCHIES ===")
# paths_meaningful = find_meaningful_paths(graph, start_node, end_node)
# print(f"Meaningful paths: {len(paths_meaningful):,}")

start_time = time.time()
print("\n=== MECHANISTIC ONLY ===")
paths_mechanistic = find_mechanistic_paths(graph, start_node, end_node)
print(f"Mechanistic paths: {len(paths_mechanistic):,}")
print(f"Mechanistic paths took: {time.time() - start_time}")

# %%
"""Run all the diagnostics."""

# Run diagnosis
results = diagnose_path_explosion(graph, start_node, end_node)

# Analyze what's in the paths
analyze_node_types(graph, start_node, end_node)
analyze_predicates(graph, start_node, end_node)

# %%
"""Save output of the current paths."""

with open(f"{start_node}_{end_node}_output.tsv", "w") as f:
    tsv_writer = csv.writer(f, delimiter="\t")

    tsv_header = [
        "path",
        "categories",
        "first_hop_predicates",
        "second_hop_predicates",
        "third_hop_predicates",
        "path_curies",
    ]
    tsv_writer.writerow(tsv_header)

    for path in paths_mechanistic:
        tsv_writer.writerow([
            f"{path['n0']['name']}->{path['n1']['name']}->{path['n2']['name']}->{path['n3']['name']}",
            f"{path['n0']['category']}->{path['n1']['category']}->{path['n2']['category']}->{path['n3']['category']}",
            path['e0']['predicate'],
            path['e1']['predicate'],
            path['e2']['predicate'],
            f"{path['n0']['id']}->{path['n1']['id']}->{path['n2']['id']}->{path['n3']['id']}",
        ])

# %%
import json
start_node = "CHEBI:45783"
paths = do_one_hop(graph, start_node)

print(len(paths))

path_obj = []
for path in paths:
    o = graph.get_node_id(path)
    path_obj.append((start_node, o))

with open("imatinib.json", "w", encoding="utf-8") as f:
    json.dump(path_obj, f, indent=2)
# Out:
# 6395

# %%
"""Check all edges for number of neighbors."""

line_count = 0
edges = []

with open("../02_04_2026/edges.jsonl", "r", encoding="utf-8") as f:
    for line in f:
        if line_count % 1_000_000 == 0:
            print(f"  Processed {line_count:,} edges...")

        data = json.loads(line)
        if (
            data["predicate"] == "biolink:affects" and
            (
                data["subject"] == "NCBIGene:2277" or
                data["object"] == "NCBIGene:2277"
            ) and
            (
                data["object"] == "CHEBI:30742" or
                data["subject"] == "CHEBI:30742"
            )
        ):
            edges.append(data)
        # if line_count % 1000 == 0:
        #     edges.append(data)

        # if data["predicate"] == "biolink:genetic_association":
        #     if (
        #         "biolink:Gene" in nodes[data["subject"]]["category"] and
        #         "biolink:DiseaseOrPhenotypicFeature" in nodes[data["object"]]["category"]
        #     ):
        #         print(data)
        #         break
        # if line_count % 10_000 == 0:
        #     edges.append(data)
        # if data["subject"] == "MONDO:0007186" and data["object"] == "MONDO:0007186":
        #     neighbors += 1
        #     edges.append(data)
        # if data["subject"] == "MONDO:0004979" or data["object"] == "MONDO:0004979":
        #     neighbors += 1
        line_count += 1
        if len(edges) > 1000:
            break

with open("./sample_edges.json", "w", encoding="utf-8") as f:
    json.dump(edges, f, indent=2)
# Out:
#   Processed 0 edges...
#   Processed 1,000,000 edges...
#   Processed 2,000,000 edges...
#   Processed 3,000,000 edges...
#   Processed 4,000,000 edges...
#   Processed 5,000,000 edges...
#   Processed 6,000,000 edges...
#   Processed 7,000,000 edges...
#   Processed 8,000,000 edges...
#   Processed 9,000,000 edges...
#   Processed 10,000,000 edges...
#   Processed 11,000,000 edges...
#   Processed 12,000,000 edges...
#   Processed 13,000,000 edges...
#   Processed 14,000,000 edges...
#   Processed 15,000,000 edges...
#   Processed 16,000,000 edges...
#   Processed 17,000,000 edges...
#   Processed 18,000,000 edges...
#   Processed 19,000,000 edges...
#   Processed 20,000,000 edges...
#   Processed 21,000,000 edges...
#   Processed 22,000,000 edges...
#   Processed 23,000,000 edges...
#   Processed 24,000,000 edges...
#   Processed 25,000,000 edges...
#   Processed 26,000,000 edges...
#   Processed 27,000,000 edges...
#   Processed 28,000,000 edges...
#   Processed 29,000,000 edges...
#   Processed 30,000,000 edges...
#   Processed 31,000,000 edges...
#   Processed 32,000,000 edges...
#   Processed 33,000,000 edges...
#   Processed 34,000,000 edges...
#   Processed 35,000,000 edges...
#   Processed 36,000,000 edges...
#   Processed 37,000,000 edges...
#   Processed 38,000,000 edges...

# %%
lookup_paths = lookup(graph, {
    "message": {
      "query_graph": {
        "nodes": {
          "SN": {
            "categories": [
              "biolink:ChemicalEntity"
            ]
          },
          "ON": {
            "ids": [
              "MONDO:0007186"
            ],
            "categories": [
              "biolink:DiseaseOrPhenotypicFeature"
            ]
          },
          "e": {
            "categories": [
              "biolink:ChemicalEntity"
            ]
          },
          "i": {
            "categories": [
              "biolink:BiologicalEntity"
            ]
          }
        },
        "edges": {
          "edge_0": {
            "subject": "e",
            "object": "ON",
            "predicates": [
              "biolink:treats"
            ]
          },
          "edge_1": {
            "subject": "i",
            "object": "SN",
            "predicates": [
              "biolink:affects"
            ],
            "qualifier_constraints": [
              {
                "qualifier_set": [
                  {
                    "qualifier_type_id": "biolink:object_aspect_qualifier",
                    "qualifier_value": "activity_or_abundance"
                  },
                  {
                    "qualifier_type_id": "biolink:object_direction_qualifier",
                    "qualifier_value": "decreased"
                  }
                ]
              }
            ]
          },
          "edge_2": {
            "subject": "i",
            "object": "e",
            "predicates": [
              "biolink:affects"
            ],
            "qualifier_constraints": [
              {
                "qualifier_set": [
                  {
                    "qualifier_type_id": "biolink:object_aspect_qualifier",
                    "qualifier_value": "activity_or_abundance"
                  },
                  {
                    "qualifier_type_id": "biolink:object_direction_qualifier",
                    "qualifier_value": "decreased"
                  }
                ]
              }
            ]
          }
        }
      }
    }
  }, bmt)

with open("../12_17_2025/heartburn_response.json", "w") as f:
    json.dump(lookup_paths, f, indent=2)
# Out:
# Using provided BMT instance
# Query graph: 4 nodes, 3 edges
#
# Processing edge 'edge_0': e -> ON
#   Query predicates: ['biolink:treats']
#   Expanded to 3 forward, 0 inverse predicates
#   Backward search from 1 pinned nodes
#   Traversed 4,935 total incoming neighbors
#   Found 152 matches in 0.030s
#   Found 152 matching edges
#   Remaining edges: 2
#
# Processing edge 'edge_2': i -> e
#   Query predicates: ['biolink:affects']
#   Expanded to 10 forward, 0 inverse predicates
#   Backward search from 150 pinned nodes
#   Traversed 11,591 total incoming neighbors
#   Found 21 matches in 0.059s
#   Found 21 matching edges
#   Remaining edges: 1
#
# Processing edge 'edge_1': i -> SN
#   Query predicates: ['biolink:affects']
#   Expanded to 10 forward, 0 inverse predicates
#   Forward search from 20 pinned nodes
#   Traversed 26,432 total neighbors
#   Found 26 matches in 0.023s
#   Found 26 matching edges
#   Remaining edges: 0
#
# Reconstructing complete paths...
#   Join order: ['edge_2', 'edge_1', 'edge_0']
#   Starting with 21 paths from edge 'edge_2'
#   Join 1/2: Adding edge 'edge_1' (21 paths)... -> 30 paths (0.00s)
#   Join 2/2: Adding edge 'edge_0' (30 paths)... -> 30 paths (0.00s)
#   Path reconstruction took 0.00s
#   Enriching 30 paths...
#   Cached properties for 30 unique nodes (0.00s)
#   Enrichment took 0.00s
# Found 30 complete paths
#   Grouped into 30 unique node paths (0.00s)
#   Built 30 results (0.00s)
#   Post-processing total: 0.00s

# %%
import httpx

with open("./expanded_messages.json", "r", encoding="utf-8") as f:
    messages = json.load(f)

all_results = 0
for indx, message in enumerate(messages):
    message["parameters"]["tiers"] = [1]
    t0 = time.perf_counter()
    try:
        with httpx.Client(timeout=60) as client:
            print(message)
            response = client.post(
                "https://automat.renci.org/translatorkg/query",
                json=message,
            )
            response.raise_for_status()
            response = response.json()
            with open(f"heartburn_responses/response_neo4j_{indx}.json", "w", encoding="utf-8") as f:
                json.dump(response, f, indent=2)
            num_results = len((response.get("message") or {}).get("results") or [])
            result = validate_trapi_response(graph, response)
            print(result.summary())
    except httpx.ReadTimeout:
        print("Timed out")
        num_results = 0
    except httpx.HTTPError as e:
        print("Got bad response:", response.content)
        num_results = 0
    print(f"Returned {num_results} results")
    all_results += num_results
    t1 = time.perf_counter()
    print(f"Query took {t1 - t0} seconds")

print("Total results:", all_results)
# Out:
# {'message': {'query_graph': {'nodes': {'ON': {'categories': ['biolink:Disease'], 'ids': ['MONDO:0007186']}, 'SN': {'categories': ['biolink:ChemicalEntity']}}, 'edges': {'t_edge': {'subject': 'SN', 'object': 'ON', 'predicates': ['biolink:treats']}}}}, 'parameters': {'tiers': [1], 'timeout': 210}}
# Validation PASSED
#   Total paths: 150
#   Valid paths: 150
#   Invalid paths: 0
# Returned 150 results
# Query took 0.9066832909593359 seconds
# {'message': {'query_graph': {'nodes': {'SN': {'categories': ['biolink:ChemicalEntity']}, 'ON': {'ids': ['MONDO:0007186'], 'categories': ['biolink:DiseaseOrPhenotypicFeature']}, 'g': {'categories': ['biolink:Gene']}}, 'edges': {'edge_0': {'subject': 'g', 'object': 'SN', 'predicates': ['biolink:affects_response_to']}, 'edge_1': {'subject': 'SN', 'object': 'ON', 'predicates': ['biolink:treats_or_applied_or_studied_to_treat']}, 'edge_2': {'subject': 'g', 'object': 'ON', 'predicates': ['biolink:genetic_association']}}}}, 'parameters': {'tiers': [1], 'timeout': 210}, 'log_level': 'DEBUG'}
# Got bad response: b'{"message":"A query was made with the following predicates, but none of them or their descendants are in the graph queried: [\'biolink:affects_response_to\']"}'
# Returned 0 results
# Query took 0.20740654197288677 seconds
# {'message': {'query_graph': {'nodes': {'SN': {'categories': ['biolink:ChemicalEntity']}, 'ON': {'ids': ['MONDO:0007186'], 'categories': ['biolink:DiseaseOrPhenotypicFeature']}, 'h': {'categories': ['biolink:ChemicalEntity']}}, 'edges': {'edge_0': {'subject': 'SN', 'object': 'ON', 'predicates': ['biolink:treats_or_applied_or_studied_to_treat']}, 'edge_1': {'subject': 'h', 'object': 'ON', 'predicates': ['biolink:treats_or_applied_or_studied_to_treat']}, 'edge_2': {'subject': 'SN', 'object': 'h', 'predicates': ['biolink:similar_to']}}}}, 'parameters': {'tiers': [1], 'timeout': 210}, 'log_level': 'DEBUG'}
# Validation PASSED
#   Total paths: 0
#   Valid paths: 0
#   Invalid paths: 0
# Returned 0 results
# Query took 0.2595127910026349 seconds
# {'message': {'query_graph': {'nodes': {'SN': {'categories': ['biolink:ChemicalEntity']}, 'ON': {'ids': ['MONDO:0007186'], 'categories': ['biolink:DiseaseOrPhenotypicFeature']}, 'h': {'categories': ['biolink:Gene']}}, 'edges': {'edge_0': {'subject': 'SN', 'object': 'ON', 'predicates': ['biolink:treats_or_applied_or_studied_to_treat']}, 'edge_1': {'subject': 'h', 'object': 'ON', 'predicates': ['biolink:genetic_association']}, 'edge_2': {'subject': 'SN', 'object': 'h', 'predicates': ['biolink:interacts_with']}}}}, 'parameters': {'tiers': [1], 'timeout': 210}, 'log_level': 'DEBUG'}
# Got bad response: b'{"message":"A query was made with the following predicates, but none of them or their descendants are in the graph queried: [\'biolink:genetic_association\']"}'
# Returned 0 results
# Query took 0.1490312499809079 seconds
# {'message': {'query_graph': {'nodes': {'SN': {'categories': ['biolink:ChemicalEntity']}, 'ON': {'ids': ['MONDO:0007186'], 'categories': ['biolink:DiseaseOrPhenotypicFeature']}, 'g': {'categories': ['biolink:Gene']}}, 'edges': {'edge_0': {'subject': 'g', 'object': 'SN', 'predicates': ['biolink:affects'], 'qualifier_constraints': [{'qualifier_set': [{'qualifier_type_id': 'biolink:object_aspect_qualifier', 'qualifier_value': 'activity_or_abundance'}]}]}, 'edge_1': {'subject': 'SN', 'object': 'ON', 'predicates': ['biolink:treats_or_applied_or_studied_to_treat']}, 'edge_2': {'subject': 'g', 'object': 'ON', 'predicates': ['biolink:genetic_association']}}}}, 'parameters': {'tiers': [1], 'timeout': 210}, 'log_level': 'DEBUG'}
# Got bad response: b'{"message":"A query was made with the following predicates, but none of them or their descendants are in the graph queried: [\'biolink:genetic_association\']"}'
# Returned 0 results
# Query took 0.1650604999740608 seconds
# {'message': {'query_graph': {'nodes': {'SN': {'categories': ['biolink:ChemicalEntity']}, 'ON': {'ids': ['MONDO:0007186'], 'categories': ['biolink:DiseaseOrPhenotypicFeature']}, 'h': {'categories': ['biolink:Gene']}}, 'edges': {'edge_0': {'subject': 'SN', 'object': 'ON', 'predicates': ['biolink:treats_or_applied_or_studied_to_treat']}, 'edge_1': {'subject': 'h', 'object': 'ON', 'predicates': ['biolink:genetic_association']}, 'edge_2': {'subject': 'SN', 'object': 'h', 'predicates': ['biolink:affects'], 'qualifier_constraints': [{'qualifier_set': [{'qualifier_type_id': 'biolink:object_aspect_qualifier', 'qualifier_value': 'secretion'}, {'qualifier_type_id': 'biolink:object_direction_qualifier', 'qualifier_value': 'increased'}]}]}}}}, 'parameters': {'tiers': [1], 'timeout': 210}, 'log_level': 'DEBUG'}
# Got bad response: b'{"message":"A query was made with the following predicates, but none of them or their descendants are in the graph queried: [\'biolink:genetic_association\']"}'
# Returned 0 results
# Query took 0.154918166983407 seconds
# {'message': {'query_graph': {'nodes': {'SN': {'categories': ['biolink:ChemicalEntity']}, 'ON': {'ids': ['MONDO:0007186'], 'categories': ['biolink:DiseaseOrPhenotypicFeature']}, 'h': {'categories': ['biolink:Disease']}}, 'edges': {'edge_0': {'subject': 'SN', 'object': 'ON', 'predicates': ['biolink:treats_or_applied_or_studied_to_treat']}, 'edge_1': {'subject': 'SN', 'object': 'h', 'predicates': ['biolink:treats_or_applied_or_studied_to_treat']}, 'edge_2': {'subject': 'h', 'object': 'ON', 'predicates': ['biolink:has_phenotype']}}}}, 'parameters': {'tiers': [1], 'timeout': 210}, 'log_level': 'DEBUG'}
# Validation PASSED
#   Total paths: 1181
#   Valid paths: 1181
#   Invalid paths: 0
# Returned 1181 results
# Query took 2.908861041010823 seconds
# {'message': {'query_graph': {'nodes': {'SN': {'categories': ['biolink:ChemicalEntity']}, 'ON': {'ids': ['MONDO:0007186'], 'categories': ['biolink:DiseaseOrPhenotypicFeature']}, 'h': {'categories': ['biolink:Gene']}}, 'edges': {'edge_0': {'subject': 'SN', 'object': 'ON', 'predicates': ['biolink:treats_or_applied_or_studied_to_treat']}, 'edge_1': {'subject': 'h', 'object': 'ON', 'predicates': ['biolink:genetic_association']}, 'edge_2': {'subject': 'SN', 'object': 'h', 'predicates': ['biolink:affects'], 'qualifier_constraints': [{'qualifier_set': [{'qualifier_type_id': 'biolink:object_aspect_qualifier', 'qualifier_value': 'transport'}, {'qualifier_type_id': 'biolink:object_direction_qualifier', 'qualifier_value': 'decreased'}]}]}}}}, 'parameters': {'tiers': [1], 'timeout': 210}, 'log_level': 'DEBUG'}
# Got bad response: b'{"message":"A query was made with the following predicates, but none of them or their descendants are in the graph queried: [\'biolink:genetic_association\']"}'
# Returned 0 results
# Query took 0.16500345902750269 seconds
# {'message': {'query_graph': {'nodes': {'SN': {'categories': ['biolink:ChemicalEntity']}, 'ON': {'ids': ['MONDO:0007186'], 'categories': ['biolink:DiseaseOrPhenotypicFeature']}, 'h': {'categories': ['biolink:Gene']}}, 'edges': {'edge_0': {'subject': 'SN', 'object': 'ON', 'predicates': ['biolink:treats_or_applied_or_studied_to_treat']}, 'edge_1': {'subject': 'h', 'object': 'ON', 'predicates': ['biolink:genetic_association']}, 'edge_2': {'subject': 'SN', 'object': 'h', 'predicates': ['biolink:affects'], 'qualifier_constraints': [{'qualifier_set': [{'qualifier_type_id': 'biolink:object_aspect_qualifier', 'qualifier_value': 'molecular_interaction'}, {'qualifier_type_id': 'biolink:object_direction_qualifier', 'qualifier_value': 'decreased'}]}]}}}}, 'parameters': {'tiers': [1], 'timeout': 210}, 'log_level': 'DEBUG'}
# Got bad response: b'{"message":"A query was made with the following predicates, but none of them or their descendants are in the graph queried: [\'biolink:genetic_association\']"}'
# Returned 0 results
# Query took 0.15720212500309572 seconds
# {'message': {'query_graph': {'nodes': {'SN': {'categories': ['biolink:ChemicalEntity']}, 'ON': {'ids': ['MONDO:0007186'], 'categories': ['biolink:DiseaseOrPhenotypicFeature']}, 'e': {'categories': ['biolink:ChemicalEntity']}, 'i': {'categories': ['biolink:BiologicalProcess']}}, 'edges': {'edge_0': {'subject': 'e', 'object': 'ON', 'predicates': ['biolink:treats_or_applied_or_studied_to_treat']}, 'edge_1': {'subject': 'i', 'object': 'SN', 'predicates': ['biolink:has_output']}, 'edge_2': {'subject': 'i', 'object': 'e', 'predicates': ['biolink:has_output']}}}}, 'parameters': {'tiers': [1], 'timeout': 210}, 'log_level': 'DEBUG'}
# Validation PASSED
#   Total paths: 0
#   Valid paths: 0
#   Invalid paths: 0
# Returned 0 results
# Query took 0.2415260830312036 seconds
# {'message': {'query_graph': {'nodes': {'SN': {'categories': ['biolink:ChemicalEntity']}, 'ON': {'ids': ['MONDO:0007186'], 'categories': ['biolink:DiseaseOrPhenotypicFeature']}, 'i': {'categories': ['biolink:ChemicalEntity']}, 'f': {'categories': ['biolink:ChemicalEntity']}}, 'edges': {'edge_0': {'subject': 'i', 'object': 'ON', 'predicates': ['biolink:treats_or_applied_or_studied_to_treat']}, 'edge_1': {'subject': 'SN', 'object': 'f', 'predicates': ['biolink:has_part']}, 'edge_2': {'subject': 'i', 'object': 'f', 'predicates': ['biolink:has_part']}}}}, 'parameters': {'tiers': [1], 'timeout': 210}, 'log_level': 'DEBUG'}
# Validation PASSED
#   Total paths: 0
#   Valid paths: 0
#   Invalid paths: 0
# Returned 0 results
# Query took 0.1867597500095144 seconds
# {'message': {'query_graph': {'nodes': {'SN': {'categories': ['biolink:ChemicalEntity']}, 'ON': {'ids': ['MONDO:0007186'], 'categories': ['biolink:DiseaseOrPhenotypicFeature']}, 'e': {'categories': ['biolink:ChemicalEntity']}, 'i': {'categories': ['biolink:NamedThing']}}, 'edges': {'edge_0': {'subject': 'e', 'object': 'ON', 'predicates': ['biolink:treats_or_applied_or_studied_to_treat']}, 'edge_1': {'subject': 'i', 'object': 'SN', 'predicates': ['biolink:has_part']}, 'edge_2': {'subject': 'i', 'object': 'e', 'predicates': ['biolink:has_part']}}}}, 'parameters': {'tiers': [1], 'timeout': 210}, 'log_level': 'DEBUG'}
# Validation PASSED
#   Total paths: 0
#   Valid paths: 0
#   Invalid paths: 0
# Returned 0 results
# Query took 0.18170050001936033 seconds
# {'message': {'query_graph': {'nodes': {'SN': {'categories': ['biolink:ChemicalEntity']}, 'ON': {'ids': ['MONDO:0007186'], 'categories': ['biolink:DiseaseOrPhenotypicFeature']}, 'f': {'categories': ['biolink:Disease']}}, 'edges': {'edge_0': {'subject': 'SN', 'object': 'f', 'predicates': ['biolink:treats_or_applied_or_studied_to_treat']}, 'edge_1': {'subject': 'f', 'object': 'ON', 'predicates': ['biolink:has_phenotype']}, 'edge_2': {'subject': 'ON', 'object': 'f', 'predicates': ['biolink:has_phenotype']}}}}, 'parameters': {'tiers': [1], 'timeout': 210}, 'log_level': 'DEBUG'}
# Validation PASSED
#   Total paths: 391
#   Valid paths: 391
#   Invalid paths: 0
# Returned 391 results
# Query took 0.9213918339810334 seconds
# {'message': {'query_graph': {'nodes': {'SN': {'categories': ['biolink:ChemicalEntity']}, 'ON': {'ids': ['MONDO:0007186'], 'categories': ['biolink:DiseaseOrPhenotypicFeature']}, 'e': {'categories': ['biolink:ChemicalEntity']}, 'i': {'categories': ['biolink:BiologicalEntity']}}, 'edges': {'edge_0': {'subject': 'e', 'object': 'ON', 'predicates': ['biolink:treats']}, 'edge_1': {'subject': 'i', 'object': 'SN', 'predicates': ['biolink:affects'], 'qualifier_constraints': [{'qualifier_set': [{'qualifier_type_id': 'biolink:object_aspect_qualifier', 'qualifier_value': 'activity_or_abundance'}, {'qualifier_type_id': 'biolink:object_direction_qualifier', 'qualifier_value': 'decreased'}]}]}, 'edge_2': {'subject': 'i', 'object': 'e', 'predicates': ['biolink:affects'], 'qualifier_constraints': [{'qualifier_set': [{'qualifier_type_id': 'biolink:object_aspect_qualifier', 'qualifier_value': 'activity_or_abundance'}, {'qualifier_type_id': 'biolink:object_direction_qualifier', 'qualifier_value': 'decreased'}]}]}}}}, 'parameters': {'tiers': [1], 'timeout': 210}, 'log_level': 'DEBUG'}
# Validation PASSED
#   Total paths: 36
#   Valid paths: 36
#   Invalid paths: 0
# Returned 36 results
# Query took 0.38350395899033174 seconds
# {'message': {'query_graph': {'nodes': {'SN': {'categories': ['biolink:ChemicalEntity']}, 'ON': {'ids': ['MONDO:0007186'], 'categories': ['biolink:DiseaseOrPhenotypicFeature']}, 'e': {'categories': ['biolink:ChemicalEntity']}, 'i': {'categories': ['biolink:BiologicalEntity']}}, 'edges': {'edge_0': {'subject': 'e', 'object': 'ON', 'predicates': ['biolink:treats_or_applied_or_studied_to_treat']}, 'edge_1': {'subject': 'i', 'object': 'SN', 'predicates': ['biolink:affects'], 'qualifier_constraints': [{'qualifier_set': [{'qualifier_type_id': 'biolink:object_aspect_qualifier', 'qualifier_value': 'metabolic_processing'}, {'qualifier_type_id': 'biolink:object_direction_qualifier', 'qualifier_value': 'decreased'}]}]}, 'edge_2': {'subject': 'i', 'object': 'e', 'predicates': ['biolink:affects'], 'qualifier_constraints': [{'qualifier_set': [{'qualifier_type_id': 'biolink:object_aspect_qualifier', 'qualifier_value': 'metabolic_processing'}, {'qualifier_type_id': 'biolink:object_direction_qualifier', 'qualifier_value': 'decreased'}]}]}}}}, 'parameters': {'tiers': [1], 'timeout': 210}, 'log_level': 'DEBUG'}
# Validation PASSED
#   Total paths: 0
#   Valid paths: 0
#   Invalid paths: 0
# Returned 0 results
# Query took 0.20945245900657028 seconds
# {'message': {'query_graph': {'nodes': {'SN': {'categories': ['biolink:ChemicalEntity']}, 'ON': {'ids': ['MONDO:0007186'], 'categories': ['biolink:DiseaseOrPhenotypicFeature']}, 'e': {'categories': ['biolink:ChemicalEntity']}, 'i': {'categories': ['biolink:BiologicalEntity']}}, 'edges': {'edge_0': {'subject': 'e', 'object': 'ON', 'predicates': ['biolink:treats_or_applied_or_studied_to_treat']}, 'edge_1': {'subject': 'i', 'object': 'SN', 'predicates': ['biolink:affects'], 'qualifier_constraints': [{'qualifier_set': [{'qualifier_type_id': 'biolink:object_aspect_qualifier', 'qualifier_value': 'transport'}, {'qualifier_type_id': 'biolink:object_direction_qualifier', 'qualifier_value': 'decreased'}]}]}, 'edge_2': {'subject': 'i', 'object': 'e', 'predicates': ['biolink:affects'], 'qualifier_constraints': [{'qualifier_set': [{'qualifier_type_id': 'biolink:object_aspect_qualifier', 'qualifier_value': 'transport'}, {'qualifier_type_id': 'biolink:object_direction_qualifier', 'qualifier_value': 'decreased'}]}]}}}}, 'parameters': {'tiers': [1], 'timeout': 210}, 'log_level': 'DEBUG'}
# Validation PASSED
#   Total paths: 0
#   Valid paths: 0
#   Invalid paths: 0
# Returned 0 results
# Query took 0.20875375001924112 seconds
# {'message': {'query_graph': {'nodes': {'SN': {'categories': ['biolink:ChemicalEntity']}, 'ON': {'ids': ['MONDO:0007186'], 'categories': ['biolink:DiseaseOrPhenotypicFeature']}, 'f': {'categories': ['biolink:Disease']}}, 'edges': {'edge_0': {'subject': 'f', 'object': 'ON', 'predicates': ['biolink:positively_correlated_with']}, 'edge_1': {'subject': 'SN', 'object': 'f', 'predicates': ['biolink:treats']}}}}, 'parameters': {'tiers': [1], 'timeout': 210}, 'log_level': 'DEBUG'}
# Validation PASSED
#   Total paths: 0
#   Valid paths: 0
#   Invalid paths: 0
# Returned 0 results
# Query took 0.1761089579667896 seconds
# {'message': {'query_graph': {'nodes': {'SN': {'categories': ['biolink:ChemicalEntity']}, 'ON': {'ids': ['MONDO:0007186'], 'categories': ['biolink:DiseaseOrPhenotypicFeature']}, 'e': {'categories': ['biolink:ChemicalEntity']}, 'i': {'categories': ['biolink:BiologicalEntity']}}, 'edges': {'edge_0': {'subject': 'e', 'object': 'ON', 'predicates': ['biolink:treats_or_applied_or_studied_to_treat']}, 'edge_1': {'subject': 'i', 'object': 'e', 'predicates': ['biolink:affects'], 'qualifier_constraints': [{'qualifier_set': [{'qualifier_type_id': 'biolink:object_aspect_qualifier', 'qualifier_value': 'abundance'}, {'qualifier_type_id': 'biolink:object_direction_qualifier', 'qualifier_value': 'increased'}]}]}, 'edge_2': {'subject': 'i', 'object': 'SN', 'predicates': ['biolink:affects'], 'qualifier_constraints': [{'qualifier_set': [{'qualifier_type_id': 'biolink:object_aspect_qualifier', 'qualifier_value': 'activity_or_abundance'}, {'qualifier_type_id': 'biolink:object_direction_qualifier', 'qualifier_value': 'increased'}]}]}}}}, 'parameters': {'tiers': [1], 'timeout': 210}, 'log_level': 'DEBUG'}
# Validation PASSED
#   Total paths: 0
#   Valid paths: 0
#   Invalid paths: 0
# Returned 0 results
# Query took 0.19040887500159442 seconds
# {'message': {'query_graph': {'nodes': {'SN': {'categories': ['biolink:ChemicalEntity']}, 'ON': {'ids': ['MONDO:0007186'], 'categories': ['biolink:DiseaseOrPhenotypicFeature']}, 'e': {'categories': ['biolink:ChemicalEntity']}, 'i': {'categories': ['biolink:BiologicalEntity']}}, 'edges': {'edge_0': {'subject': 'e', 'object': 'ON', 'predicates': ['biolink:treats_or_applied_or_studied_to_treat']}, 'edge_1': {'subject': 'i', 'object': 'SN', 'predicates': ['biolink:affects'], 'qualifier_constraints': [{'qualifier_set': [{'qualifier_type_id': 'biolink:object_aspect_qualifier', 'qualifier_value': 'secretion'}, {'qualifier_type_id': 'biolink:object_direction_qualifier', 'qualifier_value': 'increased'}]}]}, 'edge_2': {'subject': 'i', 'object': 'e', 'predicates': ['biolink:affects'], 'qualifier_constraints': [{'qualifier_set': [{'qualifier_type_id': 'biolink:object_aspect_qualifier', 'qualifier_value': 'secretion'}, {'qualifier_type_id': 'biolink:object_direction_qualifier', 'qualifier_value': 'increased'}]}]}}}}, 'parameters': {'tiers': [1], 'timeout': 210}, 'log_level': 'DEBUG'}
# Validation PASSED
#   Total paths: 0
#   Valid paths: 0
#   Invalid paths: 0
# Returned 0 results
# Query took 0.19720708299428225 seconds
# {'message': {'query_graph': {'nodes': {'SN': {'categories': ['biolink:ChemicalEntity']}, 'ON': {'ids': ['MONDO:0007186'], 'categories': ['biolink:DiseaseOrPhenotypicFeature']}, 'e': {'categories': ['biolink:ChemicalEntity']}, 'i': {'categories': ['biolink:BiologicalEntity']}}, 'edges': {'edge_0': {'subject': 'e', 'object': 'ON', 'predicates': ['biolink:treats']}, 'edge_1': {'subject': 'i', 'object': 'SN', 'predicates': ['biolink:affects'], 'qualifier_constraints': [{'qualifier_set': [{'qualifier_type_id': 'biolink:object_aspect_qualifier', 'qualifier_value': 'activity'}, {'qualifier_type_id': 'biolink:object_direction_qualifier', 'qualifier_value': 'increased'}]}]}, 'edge_2': {'subject': 'i', 'object': 'e', 'predicates': ['biolink:affects'], 'qualifier_constraints': [{'qualifier_set': [{'qualifier_type_id': 'biolink:object_aspect_qualifier', 'qualifier_value': 'activity_or_abundance'}, {'qualifier_type_id': 'biolink:object_direction_qualifier', 'qualifier_value': 'increased'}]}]}}}}, 'parameters': {'tiers': [1], 'timeout': 210}, 'log_level': 'DEBUG'}
# Validation PASSED
#   Total paths: 0
#   Valid paths: 0
#   Invalid paths: 0
# Returned 0 results
# Query took 0.2101481250138022 seconds
# {'message': {'query_graph': {'nodes': {'SN': {'categories': ['biolink:ChemicalEntity']}, 'ON': {'ids': ['MONDO:0007186'], 'categories': ['biolink:DiseaseOrPhenotypicFeature']}, 'e': {'categories': ['biolink:ChemicalEntity']}, 'i': {'categories': ['biolink:BiologicalEntity']}}, 'edges': {'edge_0': {'subject': 'e', 'object': 'ON', 'predicates': ['biolink:treats_or_applied_or_studied_to_treat']}, 'edge_1': {'subject': 'i', 'object': 'SN', 'predicates': ['biolink:affects'], 'qualifier_constraints': [{'qualifier_set': [{'qualifier_type_id': 'biolink:object_aspect_qualifier', 'qualifier_value': 'abundance'}, {'qualifier_type_id': 'biolink:object_direction_qualifier', 'qualifier_value': 'increased'}]}]}, 'edge_2': {'subject': 'i', 'object': 'e', 'predicates': ['biolink:affects'], 'qualifier_constraints': [{'qualifier_set': [{'qualifier_type_id': 'biolink:object_aspect_qualifier', 'qualifier_value': 'activity_or_abundance'}, {'qualifier_type_id': 'biolink:object_direction_qualifier', 'qualifier_value': 'increased'}]}]}}}}, 'parameters': {'tiers': [1], 'timeout': 210}, 'log_level': 'DEBUG'}
# Validation PASSED
#   Total paths: 0
#   Valid paths: 0
#   Invalid paths: 0
# Returned 0 results
# Query took 0.2178182089701295 seconds
# Total results: 1758

# %%
with open("./expanded_messages.json", "r", encoding="utf-8") as f:
    messages = json.load(f)

all_results = 0
for indx, message in enumerate(messages):
    t0 = time.perf_counter()
    print(message)
    response = lookup(graph, message, bmt, subclass=False)
    with open(f"heartburn_responses/response_gandalf_{indx}.json", "w", encoding="utf-8") as f:
        json.dump(response, f, indent=2)
    all_results += len(response["message"]["results"])
    # if len(response["message"]["results"]) > 0:
    #     with open("lookup_paths.json", "w", encoding="utf-8") as f:
    #         json.dump(response, f, indent=2)
    result = validate_trapi_response(graph, response)
    print(result.summary())
    t1 = time.perf_counter()
    print(f"Query took {t1 - t0} seconds")

print("Total results:", all_results)
# Out:
# {'message': {'query_graph': {'nodes': {'ON': {'categories': ['biolink:Disease'], 'ids': ['MONDO:0007186']}, 'SN': {'categories': ['biolink:ChemicalEntity']}}, 'edges': {'t_edge': {'subject': 'SN', 'object': 'ON', 'predicates': ['biolink:treats']}}}}, 'parameters': {'tiers': [0], 'timeout': 210}}
# Using provided BMT instance
# Query graph: 2 nodes, 1 edges
#
# Processing edge 't_edge': SN -> ON
#   Query predicates: ['biolink:treats']
#   Expanded to 3 forward, 0 inverse predicates
#   Backward search from 1 pinned nodes
#   Traversed 4,935 total incoming neighbors
#   Slow nodes (>0.1s): 1
#     Node 307937: 4,935 neighbors, 0.11s
#   Found 152 matches in 0.107s
#   Found 152 matching edges
#   Remaining edges: 0
#
# Reconstructing complete paths...
#   Join order: ['t_edge']
#   Starting with 152 paths from edge 't_edge'
#   Path reconstruction took 0.00s
#   Enriching 152 paths...
#   Cached properties for 151 unique nodes (0.00s)
#   Enrichment took 0.00s
# Found 152 complete paths
#   Grouped into 150 unique node paths (0.00s)
#   Built 150 results (0.00s)
#   Post-processing total: 0.00s
# Validation PASSED
#   Total paths: 150
#   Valid paths: 150
#   Invalid paths: 0
# Query took 0.19271100003970787 seconds
# {'message': {'query_graph': {'nodes': {'SN': {'categories': ['biolink:ChemicalEntity']}, 'ON': {'ids': ['MONDO:0007186'], 'categories': ['biolink:DiseaseOrPhenotypicFeature']}, 'g': {'categories': ['biolink:Gene']}}, 'edges': {'edge_0': {'subject': 'g', 'object': 'SN', 'predicates': ['biolink:affects_response_to']}, 'edge_1': {'subject': 'SN', 'object': 'ON', 'predicates': ['biolink:treats_or_applied_or_studied_to_treat']}, 'edge_2': {'subject': 'g', 'object': 'ON', 'predicates': ['biolink:genetic_association']}}}}, 'parameters': {'tiers': [0], 'timeout': 210}, 'log_level': 'DEBUG'}
# Using provided BMT instance
# Query graph: 3 nodes, 3 edges
#
# Processing edge 'edge_1': SN -> ON
#   Query predicates: ['biolink:treats_or_applied_or_studied_to_treat']
#   Expanded to 9 forward, 0 inverse predicates
#   Backward search from 1 pinned nodes
#   Traversed 4,935 total incoming neighbors
#   Found 537 matches in 0.035s
#   Found 537 matching edges
#   Remaining edges: 2
#
# Processing edge 'edge_2': g -> ON
#   Query predicates: ['biolink:genetic_association']
#   Expanded to 1 forward, 1 inverse predicates
#   Backward search from 1 pinned nodes
#   Traversed 5,168 total incoming neighbors
#   Found 0 matches in 0.027s
#   Found 0 matching edges
# Found no edge matches, returning 0 results.
#
# Reconstructing complete paths...
# Found 0 complete paths
#   Grouped into 0 unique node paths (0.00s)
#   Built 0 results (0.00s)
#   Post-processing total: 0.00s
# Validation PASSED
#   Total paths: 0
#   Valid paths: 0
#   Invalid paths: 0
# Query took 0.08718383399536833 seconds
# {'message': {'query_graph': {'nodes': {'SN': {'categories': ['biolink:ChemicalEntity']}, 'ON': {'ids': ['MONDO:0007186'], 'categories': ['biolink:DiseaseOrPhenotypicFeature']}, 'h': {'categories': ['biolink:ChemicalEntity']}}, 'edges': {'edge_0': {'subject': 'SN', 'object': 'ON', 'predicates': ['biolink:treats_or_applied_or_studied_to_treat']}, 'edge_1': {'subject': 'h', 'object': 'ON', 'predicates': ['biolink:treats_or_applied_or_studied_to_treat']}, 'edge_2': {'subject': 'SN', 'object': 'h', 'predicates': ['biolink:similar_to']}}}}, 'parameters': {'tiers': [0], 'timeout': 210}, 'log_level': 'DEBUG'}
# Using provided BMT instance
# Query graph: 3 nodes, 3 edges
#
# Processing edge 'edge_0': SN -> ON
#   Query predicates: ['biolink:treats_or_applied_or_studied_to_treat']
#   Expanded to 9 forward, 0 inverse predicates
#   Backward search from 1 pinned nodes
#   Traversed 4,935 total incoming neighbors
#   Found 537 matches in 0.026s
#   Found 537 matching edges
#   Remaining edges: 2
#
# Processing edge 'edge_1': h -> ON
#   Query predicates: ['biolink:treats_or_applied_or_studied_to_treat']
#   Expanded to 9 forward, 0 inverse predicates
#   Backward search from 1 pinned nodes
#   Traversed 4,935 total incoming neighbors
#   Found 537 matches in 0.026s
#   Found 537 matching edges
#   Remaining edges: 1
#
# Processing edge 'edge_2': SN -> h
#   Query predicates: ['biolink:similar_to']
#   Expanded to 6 forward, 6 inverse predicates
#   Both ends pinned: 437 start, 437 end
#   [GC] Gen 2: 10.38s, collected 0 objects
#   [GC] Gen 2: 10.38s, collected 0 objects
#   [GC] Gen 2: 10.38s, collected 0 objects
#   [GC] Gen 2: 10.38s, collected 0 objects
#   [GC] Gen 2: 10.38s, collected 0 objects
#   [GC] Gen 2: 10.38s, collected 0 objects
#     Neighbor traversal: 11.679s (1,838,224 neighbors, 0 unique targets)
#     Intersection: 0.000s
#   Found 0 matches in 11.679s
#   Found 0 matching edges
# Found no edge matches, returning 0 results.
#
# Reconstructing complete paths...
# Found 0 complete paths
#   Grouped into 0 unique node paths (0.00s)
#   Built 0 results (0.00s)
#   Post-processing total: 0.00s
#   [GC Summary] 3731 collections, 10.56s total, 33 objects collected
# Validation PASSED
#   Total paths: 0
#   Valid paths: 0
#   Invalid paths: 0
# Query took 11.75093504198594 seconds
# {'message': {'query_graph': {'nodes': {'SN': {'categories': ['biolink:ChemicalEntity']}, 'ON': {'ids': ['MONDO:0007186'], 'categories': ['biolink:DiseaseOrPhenotypicFeature']}, 'h': {'categories': ['biolink:Gene']}}, 'edges': {'edge_0': {'subject': 'SN', 'object': 'ON', 'predicates': ['biolink:treats_or_applied_or_studied_to_treat']}, 'edge_1': {'subject': 'h', 'object': 'ON', 'predicates': ['biolink:genetic_association']}, 'edge_2': {'subject': 'SN', 'object': 'h', 'predicates': ['biolink:interacts_with']}}}}, 'parameters': {'tiers': [0], 'timeout': 210}, 'log_level': 'DEBUG'}
# Using provided BMT instance
# Query graph: 3 nodes, 3 edges
#
# Processing edge 'edge_0': SN -> ON
#   Query predicates: ['biolink:treats_or_applied_or_studied_to_treat']
#   Expanded to 9 forward, 0 inverse predicates
#   Backward search from 1 pinned nodes
#   Traversed 4,935 total incoming neighbors
#   Found 537 matches in 0.029s
#   Found 537 matching edges
#   Remaining edges: 2
#
# Processing edge 'edge_1': h -> ON
#   Query predicates: ['biolink:genetic_association']
#   Expanded to 1 forward, 1 inverse predicates
#   Backward search from 1 pinned nodes
#   Traversed 5,168 total incoming neighbors
#   Found 0 matches in 0.028s
#   Found 0 matching edges
# Found no edge matches, returning 0 results.
#
# Reconstructing complete paths...
# Found 0 complete paths
#   Grouped into 0 unique node paths (0.00s)
#   Built 0 results (0.00s)
#   Post-processing total: 0.00s
# Validation PASSED
#   Total paths: 0
#   Valid paths: 0
#   Invalid paths: 0
# Query took 0.07694454200100154 seconds
# {'message': {'query_graph': {'nodes': {'SN': {'categories': ['biolink:ChemicalEntity']}, 'ON': {'ids': ['MONDO:0007186'], 'categories': ['biolink:DiseaseOrPhenotypicFeature']}, 'g': {'categories': ['biolink:Gene']}}, 'edges': {'edge_0': {'subject': 'g', 'object': 'SN', 'predicates': ['biolink:affects'], 'qualifier_constraints': [{'qualifier_set': [{'qualifier_type_id': 'biolink:object_aspect_qualifier', 'qualifier_value': 'activity_or_abundance'}]}]}, 'edge_1': {'subject': 'SN', 'object': 'ON', 'predicates': ['biolink:treats_or_applied_or_studied_to_treat']}, 'edge_2': {'subject': 'g', 'object': 'ON', 'predicates': ['biolink:genetic_association']}}}}, 'parameters': {'tiers': [0], 'timeout': 210}, 'log_level': 'DEBUG'}
# Using provided BMT instance
# Query graph: 3 nodes, 3 edges
#
# Processing edge 'edge_1': SN -> ON
#   Query predicates: ['biolink:treats_or_applied_or_studied_to_treat']
#   Expanded to 9 forward, 0 inverse predicates
#   Backward search from 1 pinned nodes
#   Traversed 4,935 total incoming neighbors
#   Found 537 matches in 0.027s
#   Found 537 matching edges
#   Remaining edges: 2
#
# Processing edge 'edge_2': g -> ON
#   Query predicates: ['biolink:genetic_association']
#   Expanded to 1 forward, 1 inverse predicates
#   Backward search from 1 pinned nodes
#   Traversed 5,168 total incoming neighbors
#   Found 0 matches in 0.030s
#   Found 0 matching edges
# Found no edge matches, returning 0 results.
#
# Reconstructing complete paths...
# Found 0 complete paths
#   Grouped into 0 unique node paths (0.00s)
#   Built 0 results (0.00s)
#   Post-processing total: 0.00s
# Validation PASSED
#   Total paths: 0
#   Valid paths: 0
#   Invalid paths: 0
# Query took 0.0726478339638561 seconds
# {'message': {'query_graph': {'nodes': {'SN': {'categories': ['biolink:ChemicalEntity']}, 'ON': {'ids': ['MONDO:0007186'], 'categories': ['biolink:DiseaseOrPhenotypicFeature']}, 'h': {'categories': ['biolink:Gene']}}, 'edges': {'edge_0': {'subject': 'SN', 'object': 'ON', 'predicates': ['biolink:treats_or_applied_or_studied_to_treat']}, 'edge_1': {'subject': 'h', 'object': 'ON', 'predicates': ['biolink:genetic_association']}, 'edge_2': {'subject': 'SN', 'object': 'h', 'predicates': ['biolink:affects'], 'qualifier_constraints': [{'qualifier_set': [{'qualifier_type_id': 'biolink:object_aspect_qualifier', 'qualifier_value': 'secretion'}, {'qualifier_type_id': 'biolink:object_direction_qualifier', 'qualifier_value': 'increased'}]}]}}}}, 'parameters': {'tiers': [0], 'timeout': 210}, 'log_level': 'DEBUG'}
# Using provided BMT instance
# Query graph: 3 nodes, 3 edges
#
# Processing edge 'edge_0': SN -> ON
#   Query predicates: ['biolink:treats_or_applied_or_studied_to_treat']
#   Expanded to 9 forward, 0 inverse predicates
#   Backward search from 1 pinned nodes
#   Traversed 4,935 total incoming neighbors
#   Found 537 matches in 0.033s
#   Found 537 matching edges
#   Remaining edges: 2
#
# Processing edge 'edge_1': h -> ON
#   Query predicates: ['biolink:genetic_association']
#   Expanded to 1 forward, 1 inverse predicates
#   Backward search from 1 pinned nodes
#   Traversed 5,168 total incoming neighbors
#   Found 0 matches in 0.032s
#   Found 0 matching edges
# Found no edge matches, returning 0 results.
#
# Reconstructing complete paths...
# Found 0 complete paths
#   Grouped into 0 unique node paths (0.00s)
#   Built 0 results (0.00s)
#   Post-processing total: 0.00s
# Validation PASSED
#   Total paths: 0
#   Valid paths: 0
#   Invalid paths: 0
# Query took 0.07617608399596065 seconds
# {'message': {'query_graph': {'nodes': {'SN': {'categories': ['biolink:ChemicalEntity']}, 'ON': {'ids': ['MONDO:0007186'], 'categories': ['biolink:DiseaseOrPhenotypicFeature']}, 'h': {'categories': ['biolink:Disease']}}, 'edges': {'edge_0': {'subject': 'SN', 'object': 'ON', 'predicates': ['biolink:treats_or_applied_or_studied_to_treat']}, 'edge_1': {'subject': 'SN', 'object': 'h', 'predicates': ['biolink:treats_or_applied_or_studied_to_treat']}, 'edge_2': {'subject': 'h', 'object': 'ON', 'predicates': ['biolink:has_phenotype']}}}}, 'parameters': {'tiers': [0], 'timeout': 210}, 'log_level': 'DEBUG'}
# Using provided BMT instance
# Query graph: 3 nodes, 3 edges
#
# Processing edge 'edge_0': SN -> ON
#   Query predicates: ['biolink:treats_or_applied_or_studied_to_treat']
#   Expanded to 9 forward, 0 inverse predicates
#   Backward search from 1 pinned nodes
#   Traversed 4,935 total incoming neighbors
#   Found 537 matches in 0.036s
#   Found 537 matching edges
#   Remaining edges: 2
#
# Processing edge 'edge_2': h -> ON
#   Query predicates: ['biolink:has_phenotype']
#   Expanded to 1 forward, 0 inverse predicates
#   Backward search from 1 pinned nodes
#   Traversed 4,935 total incoming neighbors
#   Found 432 matches in 0.033s
#   Found 432 matching edges
#   Remaining edges: 1
#
# Processing edge 'edge_1': SN -> h
#   Query predicates: ['biolink:treats_or_applied_or_studied_to_treat']
#   Expanded to 9 forward, 0 inverse predicates
#   Both ends pinned: 437 start, 432 end
#     Neighbor traversal: 0.780s (919,112 neighbors, 12,822 unique targets)
#     Intersection: 0.001s
#   Found 1,801 matches in 0.781s
#   Found 1,801 matching edges
#   Remaining edges: 0
#
# Reconstructing complete paths...
#   Join order: ['edge_2', 'edge_0', 'edge_1']
#   Starting with 432 paths from edge 'edge_2'
#   Join 1/2: Adding edge 'edge_0' (432 paths)... -> 231,984 paths (0.32s)
#   Join 2/2: Adding edge 'edge_1' (231,984 paths)... -> 2,444 paths (0.15s)
#   Path reconstruction took 0.47s
#   Enriching 2,444 paths...
#   Cached properties for 510 unique nodes (0.00s)
#   Enrichment took 0.08s
# Found 2,444 complete paths
#   Grouped into 1,476 unique node paths (0.00s)
#   Built 1,476 results (0.02s)
#   Post-processing total: 0.02s
#   [GC Summary] 2159 collections, 0.16s total, 33 objects collected
# Validation PASSED
#   Total paths: 1476
#   Valid paths: 1476
#   Invalid paths: 0
# Query took 3.1663315409678034 seconds
# {'message': {'query_graph': {'nodes': {'SN': {'categories': ['biolink:ChemicalEntity']}, 'ON': {'ids': ['MONDO:0007186'], 'categories': ['biolink:DiseaseOrPhenotypicFeature']}, 'h': {'categories': ['biolink:Gene']}}, 'edges': {'edge_0': {'subject': 'SN', 'object': 'ON', 'predicates': ['biolink:treats_or_applied_or_studied_to_treat']}, 'edge_1': {'subject': 'h', 'object': 'ON', 'predicates': ['biolink:genetic_association']}, 'edge_2': {'subject': 'SN', 'object': 'h', 'predicates': ['biolink:affects'], 'qualifier_constraints': [{'qualifier_set': [{'qualifier_type_id': 'biolink:object_aspect_qualifier', 'qualifier_value': 'transport'}, {'qualifier_type_id': 'biolink:object_direction_qualifier', 'qualifier_value': 'decreased'}]}]}}}}, 'parameters': {'tiers': [0], 'timeout': 210}, 'log_level': 'DEBUG'}
# Using provided BMT instance
# Query graph: 3 nodes, 3 edges
#
# Processing edge 'edge_0': SN -> ON
#   Query predicates: ['biolink:treats_or_applied_or_studied_to_treat']
#   Expanded to 9 forward, 0 inverse predicates
#   Backward search from 1 pinned nodes
#   Traversed 4,935 total incoming neighbors
#   Found 537 matches in 0.053s
#   Found 537 matching edges
#   Remaining edges: 2
#
# Processing edge 'edge_1': h -> ON
#   Query predicates: ['biolink:genetic_association']
#   Expanded to 1 forward, 1 inverse predicates
#   Backward search from 1 pinned nodes
#   Traversed 5,168 total incoming neighbors
#   Found 0 matches in 0.028s
#   Found 0 matching edges
# Found no edge matches, returning 0 results.
#
# Reconstructing complete paths...
# Found 0 complete paths
#   Grouped into 0 unique node paths (0.00s)
#   Built 0 results (0.00s)
#   Post-processing total: 0.00s
# Validation PASSED
#   Total paths: 0
#   Valid paths: 0
#   Invalid paths: 0
# Query took 0.09898254199652001 seconds
# {'message': {'query_graph': {'nodes': {'SN': {'categories': ['biolink:ChemicalEntity']}, 'ON': {'ids': ['MONDO:0007186'], 'categories': ['biolink:DiseaseOrPhenotypicFeature']}, 'h': {'categories': ['biolink:Gene']}}, 'edges': {'edge_0': {'subject': 'SN', 'object': 'ON', 'predicates': ['biolink:treats_or_applied_or_studied_to_treat']}, 'edge_1': {'subject': 'h', 'object': 'ON', 'predicates': ['biolink:genetic_association']}, 'edge_2': {'subject': 'SN', 'object': 'h', 'predicates': ['biolink:affects'], 'qualifier_constraints': [{'qualifier_set': [{'qualifier_type_id': 'biolink:object_aspect_qualifier', 'qualifier_value': 'molecular_interaction'}, {'qualifier_type_id': 'biolink:object_direction_qualifier', 'qualifier_value': 'decreased'}]}]}}}}, 'parameters': {'tiers': [0], 'timeout': 210}, 'log_level': 'DEBUG'}
# Using provided BMT instance
# Query graph: 3 nodes, 3 edges
#
# Processing edge 'edge_0': SN -> ON
#   Query predicates: ['biolink:treats_or_applied_or_studied_to_treat']
#   Expanded to 9 forward, 0 inverse predicates
#   Backward search from 1 pinned nodes
#   Traversed 4,935 total incoming neighbors
#   Found 537 matches in 0.027s
#   Found 537 matching edges
#   Remaining edges: 2
#
# Processing edge 'edge_1': h -> ON
#   Query predicates: ['biolink:genetic_association']
#   Expanded to 1 forward, 1 inverse predicates
#   Backward search from 1 pinned nodes
#   Traversed 5,168 total incoming neighbors
#   Found 0 matches in 0.028s
#   Found 0 matching edges
# Found no edge matches, returning 0 results.
#
# Reconstructing complete paths...
# Found 0 complete paths
#   Grouped into 0 unique node paths (0.00s)
#   Built 0 results (0.00s)
#   Post-processing total: 0.00s
# Validation PASSED
#   Total paths: 0
#   Valid paths: 0
#   Invalid paths: 0
# Query took 0.07088549999753013 seconds
# {'message': {'query_graph': {'nodes': {'SN': {'categories': ['biolink:ChemicalEntity']}, 'ON': {'ids': ['MONDO:0007186'], 'categories': ['biolink:DiseaseOrPhenotypicFeature']}, 'e': {'categories': ['biolink:ChemicalEntity']}, 'i': {'categories': ['biolink:BiologicalProcess']}}, 'edges': {'edge_0': {'subject': 'e', 'object': 'ON', 'predicates': ['biolink:treats_or_applied_or_studied_to_treat']}, 'edge_1': {'subject': 'i', 'object': 'SN', 'predicates': ['biolink:has_output']}, 'edge_2': {'subject': 'i', 'object': 'e', 'predicates': ['biolink:has_output']}}}}, 'parameters': {'tiers': [0], 'timeout': 210}, 'log_level': 'DEBUG'}
# Using provided BMT instance
# Query graph: 4 nodes, 3 edges
#
# Processing edge 'edge_0': e -> ON
#   Query predicates: ['biolink:treats_or_applied_or_studied_to_treat']
#   Expanded to 9 forward, 0 inverse predicates
#   Backward search from 1 pinned nodes
#   Traversed 4,935 total incoming neighbors
#   Found 537 matches in 0.025s
#   Found 537 matching edges
#   Remaining edges: 2
#
# Processing edge 'edge_2': i -> e
#   Query predicates: ['biolink:has_output']
#   Expanded to 1 forward, 0 inverse predicates
#   Backward search from 437 pinned nodes
#   Traversed 81,204 total incoming neighbors
#   Slow nodes (>0.1s): 1
#     Node 52977: 32,432 neighbors, 0.12s
#   Found 0 matches in 0.365s
#   Found 0 matching edges
# Found no edge matches, returning 0 results.
#
# Reconstructing complete paths...
# Found 0 complete paths
#   Grouped into 0 unique node paths (0.00s)
#   Built 0 results (0.00s)
#   Post-processing total: 0.00s
# Validation PASSED
#   Total paths: 0
#   Valid paths: 0
#   Invalid paths: 0
# Query took 0.4041519580059685 seconds
# {'message': {'query_graph': {'nodes': {'SN': {'categories': ['biolink:ChemicalEntity']}, 'ON': {'ids': ['MONDO:0007186'], 'categories': ['biolink:DiseaseOrPhenotypicFeature']}, 'i': {'categories': ['biolink:ChemicalEntity']}, 'f': {'categories': ['biolink:ChemicalEntity']}}, 'edges': {'edge_0': {'subject': 'i', 'object': 'ON', 'predicates': ['biolink:treats_or_applied_or_studied_to_treat']}, 'edge_1': {'subject': 'SN', 'object': 'f', 'predicates': ['biolink:has_part']}, 'edge_2': {'subject': 'i', 'object': 'f', 'predicates': ['biolink:has_part']}}}}, 'parameters': {'tiers': [0], 'timeout': 210}, 'log_level': 'DEBUG'}
# Using provided BMT instance
# Query graph: 4 nodes, 3 edges
#
# Processing edge 'edge_0': i -> ON
#   Query predicates: ['biolink:treats_or_applied_or_studied_to_treat']
#   Expanded to 9 forward, 0 inverse predicates
#   Backward search from 1 pinned nodes
#   Traversed 4,935 total incoming neighbors
#   Found 537 matches in 0.028s
#   Found 537 matching edges
#   Remaining edges: 2
#
# Processing edge 'edge_2': i -> f
#   Query predicates: ['biolink:has_part']
#   Expanded to 7 forward, 0 inverse predicates
#   Forward search from 437 pinned nodes
#   Traversed 919,112 total neighbors
#   Found 0 matches in 0.669s
#   Found 0 matching edges
# Found no edge matches, returning 0 results.
#
# Reconstructing complete paths...
# Found 0 complete paths
#   Grouped into 0 unique node paths (0.00s)
#   Built 0 results (0.00s)
#   Post-processing total: 0.00s
# Validation PASSED
#   Total paths: 0
#   Valid paths: 0
#   Invalid paths: 0
# Query took 0.7078368340153247 seconds
# {'message': {'query_graph': {'nodes': {'SN': {'categories': ['biolink:ChemicalEntity']}, 'ON': {'ids': ['MONDO:0007186'], 'categories': ['biolink:DiseaseOrPhenotypicFeature']}, 'e': {'categories': ['biolink:ChemicalEntity']}, 'i': {'categories': ['biolink:NamedThing']}}, 'edges': {'edge_0': {'subject': 'e', 'object': 'ON', 'predicates': ['biolink:treats_or_applied_or_studied_to_treat']}, 'edge_1': {'subject': 'i', 'object': 'SN', 'predicates': ['biolink:has_part']}, 'edge_2': {'subject': 'i', 'object': 'e', 'predicates': ['biolink:has_part']}}}}, 'parameters': {'tiers': [0], 'timeout': 210}, 'log_level': 'DEBUG'}
# Using provided BMT instance
# Query graph: 4 nodes, 3 edges
#
# Processing edge 'edge_0': e -> ON
#   Query predicates: ['biolink:treats_or_applied_or_studied_to_treat']
#   Expanded to 9 forward, 0 inverse predicates
#   Backward search from 1 pinned nodes
#   Traversed 4,935 total incoming neighbors
#   Found 537 matches in 0.027s
#   Found 537 matching edges
#   Remaining edges: 2
#
# Processing edge 'edge_2': i -> e
#   Query predicates: ['biolink:has_part']
#   Expanded to 7 forward, 0 inverse predicates
#   Backward search from 437 pinned nodes
#   Traversed 81,204 total incoming neighbors
#   Slow nodes (>0.1s): 1
#     Node 52977: 32,432 neighbors, 0.14s
#   Found 0 matches in 0.390s
#   Found 0 matching edges
# Found no edge matches, returning 0 results.
#
# Reconstructing complete paths...
# Found 0 complete paths
#   Grouped into 0 unique node paths (0.00s)
#   Built 0 results (0.00s)
#   Post-processing total: 0.00s
# Validation PASSED
#   Total paths: 0
#   Valid paths: 0
#   Invalid paths: 0
# Query took 0.43265874998178333 seconds
# {'message': {'query_graph': {'nodes': {'SN': {'categories': ['biolink:ChemicalEntity']}, 'ON': {'ids': ['MONDO:0007186'], 'categories': ['biolink:DiseaseOrPhenotypicFeature']}, 'f': {'categories': ['biolink:Disease']}}, 'edges': {'edge_0': {'subject': 'SN', 'object': 'f', 'predicates': ['biolink:treats_or_applied_or_studied_to_treat']}, 'edge_1': {'subject': 'f', 'object': 'ON', 'predicates': ['biolink:has_phenotype']}, 'edge_2': {'subject': 'ON', 'object': 'f', 'predicates': ['biolink:has_phenotype']}}}}, 'parameters': {'tiers': [0], 'timeout': 210}, 'log_level': 'DEBUG'}
# Using provided BMT instance
# Query graph: 3 nodes, 3 edges
#
# Processing edge 'edge_1': f -> ON
#   Query predicates: ['biolink:has_phenotype']
#   Expanded to 1 forward, 0 inverse predicates
#   Backward search from 1 pinned nodes
#   Traversed 4,935 total incoming neighbors
#   Found 432 matches in 0.025s
#   Found 432 matching edges
#   Remaining edges: 2
#
# Processing edge 'edge_2': ON -> f
#   Query predicates: ['biolink:has_phenotype']
#   Expanded to 1 forward, 0 inverse predicates
#   Both ends pinned: 1 start, 432 end
#     Neighbor traversal: 0.000s (233 neighbors, 4 unique targets)
#     Intersection: 0.000s
#   Found 2 matches in 0.000s
#   Found 2 matching edges
#   Remaining edges: 1
#
# Processing edge 'edge_0': SN -> f
#   Query predicates: ['biolink:treats_or_applied_or_studied_to_treat']
#   Expanded to 9 forward, 0 inverse predicates
#   Backward search from 2 pinned nodes
#   Traversed 9,229 total incoming neighbors
#   Found 661 matches in 0.053s
#   Found 661 matching edges
#   Remaining edges: 0
#
# Reconstructing complete paths...
#   Join order: ['edge_2', 'edge_1', 'edge_0']
#   Starting with 2 paths from edge 'edge_2'
#   Join 1/2: Adding edge 'edge_1' (2 paths)... -> 2 paths (0.00s)
#   Join 2/2: Adding edge 'edge_0' (2 paths)... -> 661 paths (0.00s)
#   Path reconstruction took 0.00s
#   Enriching 661 paths...
#   Cached properties for 489 unique nodes (0.00s)
#   Enrichment took 0.02s
# Found 661 complete paths
#   Grouped into 544 unique node paths (0.00s)
#   Built 544 results (0.01s)
#   Post-processing total: 0.01s
# Validation PASSED
#   Total paths: 544
#   Valid paths: 544
#   Invalid paths: 0
# Query took 0.42868541699135676 seconds
# {'message': {'query_graph': {'nodes': {'SN': {'categories': ['biolink:ChemicalEntity']}, 'ON': {'ids': ['MONDO:0007186'], 'categories': ['biolink:DiseaseOrPhenotypicFeature']}, 'e': {'categories': ['biolink:ChemicalEntity']}, 'i': {'categories': ['biolink:BiologicalEntity']}}, 'edges': {'edge_0': {'subject': 'e', 'object': 'ON', 'predicates': ['biolink:treats']}, 'edge_1': {'subject': 'i', 'object': 'SN', 'predicates': ['biolink:affects'], 'qualifier_constraints': [{'qualifier_set': [{'qualifier_type_id': 'biolink:object_aspect_qualifier', 'qualifier_value': 'activity_or_abundance'}, {'qualifier_type_id': 'biolink:object_direction_qualifier', 'qualifier_value': 'decreased'}]}]}, 'edge_2': {'subject': 'i', 'object': 'e', 'predicates': ['biolink:affects'], 'qualifier_constraints': [{'qualifier_set': [{'qualifier_type_id': 'biolink:object_aspect_qualifier', 'qualifier_value': 'activity_or_abundance'}, {'qualifier_type_id': 'biolink:object_direction_qualifier', 'qualifier_value': 'decreased'}]}]}}}}, 'parameters': {'tiers': [0], 'timeout': 210}, 'log_level': 'DEBUG'}
# Using provided BMT instance
# Query graph: 4 nodes, 3 edges
#
# Processing edge 'edge_0': e -> ON
#   Query predicates: ['biolink:treats']
#   Expanded to 3 forward, 0 inverse predicates
#   Backward search from 1 pinned nodes
#   Traversed 4,935 total incoming neighbors
#   Found 152 matches in 0.032s
#   Found 152 matching edges
#   Remaining edges: 2
#
# Processing edge 'edge_2': i -> e
#   Query predicates: ['biolink:affects']
#   Expanded to 10 forward, 0 inverse predicates
#   Backward search from 150 pinned nodes
#   Traversed 11,591 total incoming neighbors
#   Found 21 matches in 0.066s
#   Found 21 matching edges
#   Remaining edges: 1
#
# Processing edge 'edge_1': i -> SN
#   Query predicates: ['biolink:affects']
#   Expanded to 10 forward, 0 inverse predicates
#   Forward search from 20 pinned nodes
#   Traversed 26,432 total neighbors
#   Found 26 matches in 0.031s
#   Found 26 matching edges
#   Remaining edges: 0
#
# Reconstructing complete paths...
#   Join order: ['edge_2', 'edge_1', 'edge_0']
#   Starting with 21 paths from edge 'edge_2'
#   Join 1/2: Adding edge 'edge_1' (21 paths)... -> 30 paths (0.00s)
#   Join 2/2: Adding edge 'edge_0' (30 paths)... -> 30 paths (0.00s)
#   Path reconstruction took 0.00s
#   Enriching 30 paths...
#   Cached properties for 30 unique nodes (0.00s)
#   Enrichment took 0.00s
# Found 30 complete paths
#   Grouped into 30 unique node paths (0.00s)
#   Built 30 results (0.00s)
#   Post-processing total: 0.00s
# Validation PASSED
#   Total paths: 30
#   Valid paths: 30
#   Invalid paths: 0
# Query took 0.17754762503318489 seconds
# {'message': {'query_graph': {'nodes': {'SN': {'categories': ['biolink:ChemicalEntity']}, 'ON': {'ids': ['MONDO:0007186'], 'categories': ['biolink:DiseaseOrPhenotypicFeature']}, 'e': {'categories': ['biolink:ChemicalEntity']}, 'i': {'categories': ['biolink:BiologicalEntity']}}, 'edges': {'edge_0': {'subject': 'e', 'object': 'ON', 'predicates': ['biolink:treats_or_applied_or_studied_to_treat']}, 'edge_1': {'subject': 'i', 'object': 'SN', 'predicates': ['biolink:affects'], 'qualifier_constraints': [{'qualifier_set': [{'qualifier_type_id': 'biolink:object_aspect_qualifier', 'qualifier_value': 'metabolic_processing'}, {'qualifier_type_id': 'biolink:object_direction_qualifier', 'qualifier_value': 'decreased'}]}]}, 'edge_2': {'subject': 'i', 'object': 'e', 'predicates': ['biolink:affects'], 'qualifier_constraints': [{'qualifier_set': [{'qualifier_type_id': 'biolink:object_aspect_qualifier', 'qualifier_value': 'metabolic_processing'}, {'qualifier_type_id': 'biolink:object_direction_qualifier', 'qualifier_value': 'decreased'}]}]}}}}, 'parameters': {'tiers': [0], 'timeout': 210}, 'log_level': 'DEBUG'}
# Using provided BMT instance
# Query graph: 4 nodes, 3 edges
#
# Processing edge 'edge_0': e -> ON
#   Query predicates: ['biolink:treats_or_applied_or_studied_to_treat']
#   Expanded to 9 forward, 0 inverse predicates
#   Backward search from 1 pinned nodes
#   Traversed 4,935 total incoming neighbors
#   Found 537 matches in 0.028s
#   Found 537 matching edges
#   Remaining edges: 2
#
# Processing edge 'edge_2': i -> e
#   Query predicates: ['biolink:affects']
#   Expanded to 10 forward, 0 inverse predicates
#   Backward search from 437 pinned nodes
#   Traversed 81,204 total incoming neighbors
#   Slow nodes (>0.1s): 1
#     Node 52977: 32,432 neighbors, 0.12s
#   Found 0 matches in 0.346s
#   Found 0 matching edges
# Found no edge matches, returning 0 results.
#
# Reconstructing complete paths...
# Found 0 complete paths
#   Grouped into 0 unique node paths (0.00s)
#   Built 0 results (0.00s)
#   Post-processing total: 0.00s
# Validation PASSED
#   Total paths: 0
#   Valid paths: 0
#   Invalid paths: 0
# Query took 0.3815177080105059 seconds
# {'message': {'query_graph': {'nodes': {'SN': {'categories': ['biolink:ChemicalEntity']}, 'ON': {'ids': ['MONDO:0007186'], 'categories': ['biolink:DiseaseOrPhenotypicFeature']}, 'e': {'categories': ['biolink:ChemicalEntity']}, 'i': {'categories': ['biolink:BiologicalEntity']}}, 'edges': {'edge_0': {'subject': 'e', 'object': 'ON', 'predicates': ['biolink:treats_or_applied_or_studied_to_treat']}, 'edge_1': {'subject': 'i', 'object': 'SN', 'predicates': ['biolink:affects'], 'qualifier_constraints': [{'qualifier_set': [{'qualifier_type_id': 'biolink:object_aspect_qualifier', 'qualifier_value': 'transport'}, {'qualifier_type_id': 'biolink:object_direction_qualifier', 'qualifier_value': 'decreased'}]}]}, 'edge_2': {'subject': 'i', 'object': 'e', 'predicates': ['biolink:affects'], 'qualifier_constraints': [{'qualifier_set': [{'qualifier_type_id': 'biolink:object_aspect_qualifier', 'qualifier_value': 'transport'}, {'qualifier_type_id': 'biolink:object_direction_qualifier', 'qualifier_value': 'decreased'}]}]}}}}, 'parameters': {'tiers': [0], 'timeout': 210}, 'log_level': 'DEBUG'}
# Using provided BMT instance
# Query graph: 4 nodes, 3 edges
#
# Processing edge 'edge_0': e -> ON
#   Query predicates: ['biolink:treats_or_applied_or_studied_to_treat']
#   Expanded to 9 forward, 0 inverse predicates
#   Backward search from 1 pinned nodes
#   Traversed 4,935 total incoming neighbors
#   Found 537 matches in 0.024s
#   Found 537 matching edges
#   Remaining edges: 2
#
# Processing edge 'edge_2': i -> e
#   Query predicates: ['biolink:affects']
#   Expanded to 10 forward, 0 inverse predicates
#   Backward search from 437 pinned nodes
#   Traversed 81,204 total incoming neighbors
#   Slow nodes (>0.1s): 1
#     Node 52977: 32,432 neighbors, 0.12s
#   Found 0 matches in 0.345s
#   Found 0 matching edges
# Found no edge matches, returning 0 results.
#
# Reconstructing complete paths...
# Found 0 complete paths
#   Grouped into 0 unique node paths (0.00s)
#   Built 0 results (0.00s)
#   Post-processing total: 0.00s
# Validation PASSED
#   Total paths: 0
#   Valid paths: 0
#   Invalid paths: 0
# Query took 0.386659208976198 seconds
# {'message': {'query_graph': {'nodes': {'SN': {'categories': ['biolink:ChemicalEntity']}, 'ON': {'ids': ['MONDO:0007186'], 'categories': ['biolink:DiseaseOrPhenotypicFeature']}, 'f': {'categories': ['biolink:Disease']}}, 'edges': {'edge_0': {'subject': 'f', 'object': 'ON', 'predicates': ['biolink:positively_correlated_with']}, 'edge_1': {'subject': 'SN', 'object': 'f', 'predicates': ['biolink:treats']}}}}, 'parameters': {'tiers': [0], 'timeout': 210}, 'log_level': 'DEBUG'}
# Using provided BMT instance
# Query graph: 3 nodes, 2 edges
#
# Processing edge 'edge_0': f -> ON
#   Query predicates: ['biolink:positively_correlated_with']
#   Expanded to 1 forward, 1 inverse predicates
#   Backward search from 1 pinned nodes
#   Traversed 5,168 total incoming neighbors
#   Found 0 matches in 0.024s
#   Found 0 matching edges
# Found no edge matches, returning 0 results.
#
# Reconstructing complete paths...
# Found 0 complete paths
#   Grouped into 0 unique node paths (0.00s)
#   Built 0 results (0.00s)
#   Post-processing total: 0.00s
# Validation PASSED
#   Total paths: 0
#   Valid paths: 0
#   Invalid paths: 0
# Query took 0.03260754200164229 seconds
# {'message': {'query_graph': {'nodes': {'SN': {'categories': ['biolink:ChemicalEntity']}, 'ON': {'ids': ['MONDO:0007186'], 'categories': ['biolink:DiseaseOrPhenotypicFeature']}, 'e': {'categories': ['biolink:ChemicalEntity']}, 'i': {'categories': ['biolink:BiologicalEntity']}}, 'edges': {'edge_0': {'subject': 'e', 'object': 'ON', 'predicates': ['biolink:treats_or_applied_or_studied_to_treat']}, 'edge_1': {'subject': 'i', 'object': 'e', 'predicates': ['biolink:affects'], 'qualifier_constraints': [{'qualifier_set': [{'qualifier_type_id': 'biolink:object_aspect_qualifier', 'qualifier_value': 'abundance'}, {'qualifier_type_id': 'biolink:object_direction_qualifier', 'qualifier_value': 'increased'}]}]}, 'edge_2': {'subject': 'i', 'object': 'SN', 'predicates': ['biolink:affects'], 'qualifier_constraints': [{'qualifier_set': [{'qualifier_type_id': 'biolink:object_aspect_qualifier', 'qualifier_value': 'activity_or_abundance'}, {'qualifier_type_id': 'biolink:object_direction_qualifier', 'qualifier_value': 'increased'}]}]}}}}, 'parameters': {'tiers': [0], 'timeout': 210}, 'log_level': 'DEBUG'}
# Using provided BMT instance
# Query graph: 4 nodes, 3 edges
#
# Processing edge 'edge_0': e -> ON
#   Query predicates: ['biolink:treats_or_applied_or_studied_to_treat']
#   Expanded to 9 forward, 0 inverse predicates
#   Backward search from 1 pinned nodes
#   Traversed 4,935 total incoming neighbors
#   Found 537 matches in 0.026s
#   Found 537 matching edges
#   Remaining edges: 2
#
# Processing edge 'edge_1': i -> e
#   Query predicates: ['biolink:affects']
#   Expanded to 10 forward, 0 inverse predicates
#   Backward search from 437 pinned nodes
#   Traversed 81,204 total incoming neighbors
#   Slow nodes (>0.1s): 1
#     Node 52977: 32,432 neighbors, 0.11s
#   Found 0 matches in 0.346s
#   Found 0 matching edges
# Found no edge matches, returning 0 results.
#
# Reconstructing complete paths...
# Found 0 complete paths
#   Grouped into 0 unique node paths (0.00s)
#   Built 0 results (0.00s)
#   Post-processing total: 0.00s
# Validation PASSED
#   Total paths: 0
#   Valid paths: 0
#   Invalid paths: 0
# Query took 0.38408591697225347 seconds
# {'message': {'query_graph': {'nodes': {'SN': {'categories': ['biolink:ChemicalEntity']}, 'ON': {'ids': ['MONDO:0007186'], 'categories': ['biolink:DiseaseOrPhenotypicFeature']}, 'e': {'categories': ['biolink:ChemicalEntity']}, 'i': {'categories': ['biolink:BiologicalEntity']}}, 'edges': {'edge_0': {'subject': 'e', 'object': 'ON', 'predicates': ['biolink:treats_or_applied_or_studied_to_treat']}, 'edge_1': {'subject': 'i', 'object': 'SN', 'predicates': ['biolink:affects'], 'qualifier_constraints': [{'qualifier_set': [{'qualifier_type_id': 'biolink:object_aspect_qualifier', 'qualifier_value': 'secretion'}, {'qualifier_type_id': 'biolink:object_direction_qualifier', 'qualifier_value': 'increased'}]}]}, 'edge_2': {'subject': 'i', 'object': 'e', 'predicates': ['biolink:affects'], 'qualifier_constraints': [{'qualifier_set': [{'qualifier_type_id': 'biolink:object_aspect_qualifier', 'qualifier_value': 'secretion'}, {'qualifier_type_id': 'biolink:object_direction_qualifier', 'qualifier_value': 'increased'}]}]}}}}, 'parameters': {'tiers': [0], 'timeout': 210}, 'log_level': 'DEBUG'}
# Using provided BMT instance
# Query graph: 4 nodes, 3 edges
#
# Processing edge 'edge_0': e -> ON
#   Query predicates: ['biolink:treats_or_applied_or_studied_to_treat']
#   Expanded to 9 forward, 0 inverse predicates
#   Backward search from 1 pinned nodes
#   Traversed 4,935 total incoming neighbors
#   Found 537 matches in 0.026s
#   Found 537 matching edges
#   Remaining edges: 2
#
# Processing edge 'edge_2': i -> e
#   Query predicates: ['biolink:affects']
#   Expanded to 10 forward, 0 inverse predicates
#   Backward search from 437 pinned nodes
#   Traversed 81,204 total incoming neighbors
#   Slow nodes (>0.1s): 1
#     Node 52977: 32,432 neighbors, 0.12s
#   Found 0 matches in 0.374s
#   Found 0 matching edges
# Found no edge matches, returning 0 results.
#
# Reconstructing complete paths...
# Found 0 complete paths
#   Grouped into 0 unique node paths (0.00s)
#   Built 0 results (0.00s)
#   Post-processing total: 0.00s
# Validation PASSED
#   Total paths: 0
#   Valid paths: 0
#   Invalid paths: 0
# Query took 0.4154723749961704 seconds
# {'message': {'query_graph': {'nodes': {'SN': {'categories': ['biolink:ChemicalEntity']}, 'ON': {'ids': ['MONDO:0007186'], 'categories': ['biolink:DiseaseOrPhenotypicFeature']}, 'e': {'categories': ['biolink:ChemicalEntity']}, 'i': {'categories': ['biolink:BiologicalEntity']}}, 'edges': {'edge_0': {'subject': 'e', 'object': 'ON', 'predicates': ['biolink:treats']}, 'edge_1': {'subject': 'i', 'object': 'SN', 'predicates': ['biolink:affects'], 'qualifier_constraints': [{'qualifier_set': [{'qualifier_type_id': 'biolink:object_aspect_qualifier', 'qualifier_value': 'activity'}, {'qualifier_type_id': 'biolink:object_direction_qualifier', 'qualifier_value': 'increased'}]}]}, 'edge_2': {'subject': 'i', 'object': 'e', 'predicates': ['biolink:affects'], 'qualifier_constraints': [{'qualifier_set': [{'qualifier_type_id': 'biolink:object_aspect_qualifier', 'qualifier_value': 'activity_or_abundance'}, {'qualifier_type_id': 'biolink:object_direction_qualifier', 'qualifier_value': 'increased'}]}]}}}}, 'parameters': {'tiers': [0], 'timeout': 210}, 'log_level': 'DEBUG'}
# Using provided BMT instance
# Query graph: 4 nodes, 3 edges
#
# Processing edge 'edge_0': e -> ON
#   Query predicates: ['biolink:treats']
#   Expanded to 3 forward, 0 inverse predicates
#   Backward search from 1 pinned nodes
#   Traversed 4,935 total incoming neighbors
#   Found 152 matches in 0.025s
#   Found 152 matching edges
#   Remaining edges: 2
#
# Processing edge 'edge_2': i -> e
#   Query predicates: ['biolink:affects']
#   Expanded to 10 forward, 0 inverse predicates
#   Backward search from 150 pinned nodes
#   Traversed 11,591 total incoming neighbors
#   Found 7 matches in 0.066s
#   Found 7 matching edges
#   Remaining edges: 1
#
# Processing edge 'edge_1': i -> SN
#   Query predicates: ['biolink:affects']
#   Expanded to 10 forward, 0 inverse predicates
#   Forward search from 7 pinned nodes
#   Traversed 11,703 total neighbors
#   Found 0 matches in 0.011s
#   Found 0 matching edges
# Found no edge matches, returning 0 results.
#
# Reconstructing complete paths...
# Found 0 complete paths
#   Grouped into 0 unique node paths (0.00s)
#   Built 0 results (0.00s)
#   Post-processing total: 0.00s
# Validation PASSED
#   Total paths: 0
#   Valid paths: 0
#   Invalid paths: 0
# Query took 0.1180282499990426 seconds
# {'message': {'query_graph': {'nodes': {'SN': {'categories': ['biolink:ChemicalEntity']}, 'ON': {'ids': ['MONDO:0007186'], 'categories': ['biolink:DiseaseOrPhenotypicFeature']}, 'e': {'categories': ['biolink:ChemicalEntity']}, 'i': {'categories': ['biolink:BiologicalEntity']}}, 'edges': {'edge_0': {'subject': 'e', 'object': 'ON', 'predicates': ['biolink:treats_or_applied_or_studied_to_treat']}, 'edge_1': {'subject': 'i', 'object': 'SN', 'predicates': ['biolink:affects'], 'qualifier_constraints': [{'qualifier_set': [{'qualifier_type_id': 'biolink:object_aspect_qualifier', 'qualifier_value': 'abundance'}, {'qualifier_type_id': 'biolink:object_direction_qualifier', 'qualifier_value': 'increased'}]}]}, 'edge_2': {'subject': 'i', 'object': 'e', 'predicates': ['biolink:affects'], 'qualifier_constraints': [{'qualifier_set': [{'qualifier_type_id': 'biolink:object_aspect_qualifier', 'qualifier_value': 'activity_or_abundance'}, {'qualifier_type_id': 'biolink:object_direction_qualifier', 'qualifier_value': 'increased'}]}]}}}}, 'parameters': {'tiers': [0], 'timeout': 210}, 'log_level': 'DEBUG'}
# Using provided BMT instance
# Query graph: 4 nodes, 3 edges
#
# Processing edge 'edge_0': e -> ON
#   Query predicates: ['biolink:treats_or_applied_or_studied_to_treat']
#   Expanded to 9 forward, 0 inverse predicates
#   Backward search from 1 pinned nodes
#   Traversed 4,935 total incoming neighbors
#   Found 537 matches in 0.025s
#   Found 537 matching edges
#   Remaining edges: 2
#
# Processing edge 'edge_2': i -> e
#   Query predicates: ['biolink:affects']
#   Expanded to 10 forward, 0 inverse predicates
#   Backward search from 437 pinned nodes
#   Traversed 81,204 total incoming neighbors
#   Slow nodes (>0.1s): 1
#     Node 52977: 32,432 neighbors, 0.12s
#   Found 7 matches in 0.342s
#   Found 7 matching edges
#   Remaining edges: 1
#
# Processing edge 'edge_1': i -> SN
#   Query predicates: ['biolink:affects']
#   Expanded to 10 forward, 0 inverse predicates
#   Forward search from 7 pinned nodes
#   Traversed 11,703 total neighbors
#   Found 0 matches in 0.012s
#   Found 0 matching edges
# Found no edge matches, returning 0 results.
#
# Reconstructing complete paths...
# Found 0 complete paths
#   Grouped into 0 unique node paths (0.00s)
#   Built 0 results (0.00s)
#   Post-processing total: 0.00s
# Validation PASSED
#   Total paths: 0
#   Valid paths: 0
#   Invalid paths: 0
# Query took 0.3917504999553785 seconds
# Total results: 2200

# %%
lookup_paths = lookup(graph, {"message": {"query_graph": {
      "nodes": {
        "SN": {
          "categories": [
            "biolink:ChemicalEntity"
          ]
        },
        "ON": {
          "ids": [
            "MONDO:0007186"
          ],
          "categories": [
            "biolink:DiseaseOrPhenotypicFeature"
          ]
        },
        "e": {
          "categories": [
            "biolink:ChemicalEntity"
          ]
        },
        "i": {
          "categories": [
            "biolink:BiologicalEntity"
          ]
        }
      },
      "edges": {
        "edge_0": {
          "subject": "e",
          "object": "ON",
          "predicates": [
            "biolink:treats"
          ]
        },
        "edge_1": {
          "subject": "i",
          "object": "SN",
          "predicates": [
            "biolink:affects"
          ],
          "qualifier_constraints": [
            {
              "qualifier_set": [
                {
                  "qualifier_type_id": "biolink:object_aspect_qualifier",
                  "qualifier_value": "activity_or_abundance"
                },
                {
                  "qualifier_type_id": "biolink:object_direction_qualifier",
                  "qualifier_value": "decreased"
                }
              ]
            }
          ]
        },
        "edge_2": {
          "subject": "i",
          "object": "e",
          "predicates": [
            "biolink:affects"
          ],
          "qualifier_constraints": [
            {
              "qualifier_set": [
                {
                  "qualifier_type_id": "biolink:object_aspect_qualifier",
                  "qualifier_value": "activity_or_abundance"
                },
                {
                  "qualifier_type_id": "biolink:object_direction_qualifier",
                  "qualifier_value": "decreased"
                }
              ]
            }
          ]
        }
      }
    }}}, bmt)

with open("lookup_paths.json", "w", encoding="utf-8") as f:
    json.dump(lookup_paths, f, indent=2)

result = validate_trapi_response(graph, lookup_paths)
print(result.summary())
# Out:
# Using provided BMT instance
# Rewriting query graph for subclass expansion (depth=1)
# Query graph: 5 nodes, 4 edges
#
# Processing edge 'ON_subclass_edge': ON -> ON_superclass
#   Subclass traversal: found 2 matches (depth=1)
#   Found 2 matching edges
#   Remaining edges: 3
#
# Processing edge 'edge_0': e -> ON
#   Query predicates: ['biolink:treats']
#   Expanded to 3 forward, 0 inverse predicates
#   Backward search from 2 pinned nodes
#   Traversed 4,954 total incoming neighbors
#   Found 152 matches in 0.028s
#   Found 152 matching edges
#   Remaining edges: 2
#
# Processing edge 'edge_2': i -> e
#   Query predicates: ['biolink:affects']
#   Expanded to 10 forward, 0 inverse predicates
#   Backward search from 150 pinned nodes
#   Traversed 11,591 total incoming neighbors
#   Found 21 matches in 0.067s
#   Found 21 matching edges
#   Remaining edges: 1
#
# Processing edge 'edge_1': i -> SN
#   Query predicates: ['biolink:affects']
#   Expanded to 10 forward, 0 inverse predicates
#   Forward search from 20 pinned nodes
#   Traversed 26,432 total neighbors
#   Found 26 matches in 0.028s
#   Found 26 matching edges
#   Remaining edges: 0
#
# Reconstructing complete paths...
#   Join order: ['ON_subclass_edge', 'edge_0', 'edge_2', 'edge_1']
#   Starting with 2 paths from edge 'ON_subclass_edge'
#   Join 1/3: Adding edge 'edge_0' (2 paths)... -> 152 paths (0.00s)
#   Join 2/3: Adding edge 'edge_2' (152 paths)... -> 21 paths (0.00s)
#   Join 3/3: Adding edge 'edge_1' (21 paths)... -> 30 paths (0.00s)
#   Path reconstruction took 0.00s
#   Enriching 30 paths...
#   Cached properties for 30 unique nodes (0.00s)
#   Enrichment took 0.00s
# Found 30 complete paths
#   Grouped into 30 unique node paths (0.00s)
#   Built 30 results (0.00s)
#   Post-processing total: 0.00s
# Validation PASSED
#   Total paths: 30
#   Valid paths: 30
#   Invalid paths: 0

# %%
asprin_to_colorectral_cancer = lookup(graph, {
  "message": {
    "query_graph": {
      "nodes": {
        "n0": {
          "ids": ["CHEBI:15365"]
        },
        "n1": {},
        "n2": {},
        "n3": {
          "ids": ["MONDO:0005575"]
        }
      },
      "edges": {
        "e0": {
          "subject": "n0",
          "object": "n1",
          "predicates": ["biolink:related_to"]
        },
        "e1": {
          "subject": "n1",
          "object": "n2",
          "predicates": ["biolink:treats", "biolink:affects", "biolink:regulates", "biolink:gene_associated_with_condition", "biolink:has_metabolite", "biolink:applied_to_treat", "biolink:directly_physically_interacts_with", "biolink:has_contraindication", "biolink:subject_of_treatment_application_or_study_for_treatment_by", "biolink:contribution_from"]
        },
        "e2": {
          "subject": "n2",
          "object": "n3",
          "predicates": ["biolink:related_to"]
        }
      }
    }
  }
}, bmt)
# Out:
# Using provided BMT instance
# Query graph: 4 nodes, 3 edges
#
# Processing edge 'e0': n0 -> n1
#   Query predicates: ['biolink:related_to']
#   Expanded to 0 forward, 0 inverse predicates
#   Forward search from 1 pinned nodes
#   [GC] Gen 1: 5.65s, collected 0 objects
#   [GC] Gen 2: 11.29s, collected 0 objects
#   Traversed 10,003 total neighbors
#   Slow nodes (>0.1s): 1
#     Node 52847: 10,003 neighbors, 16.95s
#   Found 9,207 matches in 16.951s
#   Found 9,207 matching edges
#   Remaining edges: 2
#
# Processing edge 'e2': n2 -> n3
#   Query predicates: ['biolink:related_to']
#   Expanded to 0 forward, 0 inverse predicates
#   Backward search from 1 pinned nodes
#   Traversed 6,904 total incoming neighbors
#   Slow nodes (>0.1s): 1
#     Node 306563: 6,904 neighbors, 0.14s
#   Found 6,861 matches in 0.139s
#   Found 6,861 matching edges
#   Remaining edges: 1
#
# Processing edge 'e1': n1 -> n2
#   Query predicates: ['biolink:treats', 'biolink:affects', 'biolink:regulates', 'biolink:gene_associated_with_condition', 'biolink:has_metabolite', 'biolink:applied_to_treat', 'biolink:directly_physically_interacts_with', 'biolink:has_contraindication', 'biolink:subject_of_treatment_application_or_study_for_treatment_by', 'biolink:contribution_from']
#   Expanded to 20 forward, 14 inverse predicates
#   Both ends pinned: 7171 start, 6284 end
#     Neighbor traversal: 5.475s (7,370,227 neighbors, 38,086 unique targets)
#     Intersection: 0.083s
#   Found 762,084 matches in 5.558s
#   Found 762,084 matching edges
#   Remaining edges: 0
#
# Reconstructing complete paths...
#   Join order: ['e2', 'e1', 'e0']
#   Starting with 6,861 paths from edge 'e2'
#   Join 1/2: Adding edge 'e1' (6,861 paths)... -> 999,774 paths (1.52s)
#   Join 2/2: Adding edge 'e0' (999,774 paths)... -> 2,716,942 paths (4.44s)
#   Path reconstruction took 5.96s
#   Enriching 2,716,942 paths (lightweight mode: >50,000 paths, skipping edge attributes)...
#   [GC] Gen 0: 0.13s, collected 0 objects
#   [GC] Gen 1: 0.13s, collected 0 objects
#   Cached properties for 9,091 unique nodes (0.33s)
#   [GC] Gen 0: 1.51s, collected 0 objects
#   Enrichment took 7.77s
# Found 2,716,942 complete paths
#   [GC] Gen 1: 2.24s, collected 0 objects
#   [GC] Gen 2: 15.15s, collected 0 objects
#   Grouped into 659,872 unique node paths (20.19s)
#   [GC] Gen 1: 4.53s, collected 0 objects
#   Built 659,872 results (14.51s)
#   Post-processing total: 34.70s
#   [GC Summary] 21308 collections, 41.45s total, 0 objects collected

# %%
"""Do small query."""
message = {
  "message": {
    "query_graph": {
      "nodes": {
        # "ON": {
        #   "ids": ["MONDO:0007186"],
        #   "categories": [
        #     "biolink:DiseaseOrPhenotypicFeature"
        #   ]
        # },
        # "e": {
        #   "ids": ["CHEBI:30742"],
        #   "categories": [
        #     "biolink:ChemicalEntity"
        #   ]
        # },
        "SN": {
          "ids": ["CHEBI:30742"],
          "categories": [
            "biolink:ChemicalEntity"
          ]
        },
        "i": {
            "ids": ["NCBIGene:2277"],
            "categories": [
                "biolink:BiologicalEntity"
            ]
        }
      },
      "edges": {
        # "edge_0": {
        #   "subject": "e",
        #   "object": "ON",
        #   "predicates": [
        #     "biolink:treats"
        #   ],
        #   "attribute_constraints": [],
        #   "qualifier_constraints": []
        # },
        "edge_1": {
          "subject": "i",
          "object": "SN",
          "predicates": [
            "biolink:related_to"
          ],
          "attribute_constraints": [],
          "qualifier_constraints": [
            {
              "qualifier_set": [
                {
                  "qualifier_type_id": "biolink:object_aspect_qualifier",
                  "qualifier_value": "activity_or_abundance"
                },
                {
                  "qualifier_type_id": "biolink:object_direction_qualifier",
                  "qualifier_value": "decreased"
                }
              ]
            }
          ]
        },
        # "edge_2": {
        #   "subject": "i",
        #   "object": "e",
        #   "predicates": [
        #     "biolink:affects"
        #   ],
        #   "attribute_constraints": [],
        #   "qualifier_constraints": [
        #     {
        #       "qualifier_set": [
        #         {
        #           "qualifier_type_id": "biolink:object_aspect_qualifier",
        #           "qualifier_value": "activity_or_abundance"
        #         },
        #         {
        #           "qualifier_type_id": "biolink:object_direction_qualifier",
        #           "qualifier_value": "decreased"
        #         }
        #       ]
        #     }
        #   ]
        # }
      }
    }
  }
}

t0 = time.perf_counter()

# try:
#     with httpx.Client(timeout=60) as client:
#         response = client.post(
#             "https://automat.renci.org/translatorkg/query",
#             json=message,
#         )
#         response.raise_for_status()
#         results = response.json()
#         num_results = len((results.get("message") or {}).get("results") or [])
#         result = validate_trapi_response(graph, results)
#         print(result.summary())
# except httpx.ReadTimeout:
#     print("Timed out")
#     num_results = 0
# except httpx.HTTPError as e:
#     print("Got bad response:", response.content)
#     num_results = 0

results = lookup(graph, message, bmt, subclass=True)

t1 = time.perf_counter()
print(f"Gandalf returned {len(results['message']['results'])} results in {t1 - t0}s")

with open("gandalf_missing_edge.json", "w", encoding="utf-8") as f:
    json.dump(results, f, indent=2)

# result = validate_trapi_response(graph, pathfinder_results)
# print(result.summary())
# Out:
# Using provided BMT instance
# Rewriting query graph for subclass expansion (depth=1)
# Query graph: 4 nodes, 3 edges
#
# Processing edge 'SN_subclass_edge': SN -> SN_superclass
#   Subclass traversal: found 23 matches (depth=1)
#   Found 23 matching edges
#   Remaining edges: 2
#
# Processing edge 'i_subclass_edge': i -> i_superclass
#   [GC] Gen 1: 1.40s, collected 0 objects
#   [GC] Gen 2: 1.61s, collected 12 objects
#   Subclass traversal: found 1 matches (depth=1)
#   Found 1 matching edges
#   Remaining edges: 1
#
# Processing edge 'edge_1': i -> SN
#   Query predicates: ['biolink:related_to']
#   Expanded to 0 forward, 0 inverse predicates
#   Both ends pinned: 1 start, 23 end
#     Neighbor traversal: 0.003s (2,008 neighbors, 1,801 unique targets)
#     Intersection: 0.000s
#   Found 2 matches in 0.003s
#   Found 2 matching edges
#   Remaining edges: 0
#
# Reconstructing complete paths...
#   Join order: ['i_subclass_edge', 'edge_1', 'SN_subclass_edge']
#   Starting with 1 paths from edge 'i_subclass_edge'
#   Join 1/2: Adding edge 'edge_1' (1 paths)... -> 2 paths (0.00s)
#   Join 2/2: Adding edge 'SN_subclass_edge' (2 paths)... -> 2 paths (0.00s)
#   Path reconstruction took 0.00s
#   Enriching 2 paths...
#   Cached properties for 2 unique nodes (0.01s)
#   Enrichment took 0.00s
# Found 2 complete paths
#   Grouped into 1 unique node paths (0.00s)
#   Built 1 results (0.00s)
#   Post-processing total: 0.00s
#   [GC Summary] 22 collections, 3.02s total, 329 objects collected
# Gandalf returned 1 results in 3.747329792000073s
